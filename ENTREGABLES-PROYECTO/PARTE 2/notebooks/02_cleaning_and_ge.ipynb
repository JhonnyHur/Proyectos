# %%
import pandas as pd
import unicodedata
from great_expectations.core.batch import BatchRequest
from great_expectations.dataset import PandasDataset
import great_expectations as ge
import os, json
import yaml
from great_expectations.validator.validator import Validator
from great_expectations.core.batch import RuntimeBatchRequest
from great_expectations.checkpoint import SimpleCheckpoint

# %% [markdown]
# ## **Limpieza y Normalización**

# %% [markdown]
# **Dataset Ifces 2024**

# %%
FILE_ICFES = "../data/raw/data_icfes_2024.csv"
df_icfes_2024 = pd.read_csv(FILE_ICFES, encoding="utf-8")

print("Shape:", df_icfes_2024.shape)
print(df_icfes_2024.info())
# Out:
# Shape: (626339, 53)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626339 entries, 0 to 626338
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   periodo                        626339 non-null  int64
#  1   estu_estudiante                626339 non-null  object
#  2   cole_area_ubicacion            626339 non-null  object
#  3   cole_bilingue                  626339 non-null  int64
#  4   cole_calendario                626339 non-null  object
#  5   cole_caracter                  626339 non-null  object
#  6   cole_depto_ubicacion           626339 non-null  object
#  7   cole_genero                    626339 non-null  object
#  8   cole_jornada                   626339 non-null  object
#  9   cole_mcpio_ubicacion           626339 non-null  object
#  10  cole_naturaleza                626339 non-null  object
#  11  desemp_c_naturales             626339 non-null  int64
#  12  desemp_ingles                  626339 non-null  object
#  13  desemp_lectura_critica         626339 non-null  int64
#  14  desemp_matematicas             626339 non-null  int64
#  15  desemp_sociales_ciudadanas     626339 non-null  int64
#  16  estu_dedicacioninternet        626339 non-null  object
#  17  estu_dedicacionlecturadiaria   626339 non-null  object
#  18  estu_depto_presentacion        626339 non-null  object
#  19  estu_depto_reside              626339 non-null  object
#  20  estu_genero                    626339 non-null  object
#  21  estu_grado                     626339 non-null  int64
#  22  estu_horassemanatrabaja        626339 non-null  object
#  23  estu_inse_individual           626339 non-null  float64
#  24  estu_mcpio_presentacion        626339 non-null  object
#  25  estu_mcpio_reside              626339 non-null  object
#  26  estu_nacionalidad              626339 non-null  object
#  27  estu_nse_establecimiento       626339 non-null  float64
#  28  estu_nse_individual            626339 non-null  float64
#  29  estu_pais_reside               626339 non-null  object
#  30  fami_comecarnepescadohuevo     626339 non-null  object
#  31  fami_comecerealfrutoslegumbre  626339 non-null  object
#  32  fami_comelechederivados        626339 non-null  object
#  33  fami_cuartoshogar              626339 non-null  object
#  34  fami_educacionmadre            626339 non-null  object
#  35  fami_educacionpadre            626339 non-null  object
#  36  fami_estratovivienda           626339 non-null  int64
#  37  fami_numlibros                 626339 non-null  object
#  38  fami_personashogar             626339 non-null  object
#  39  fami_tienecomputador           626339 non-null  int64
#  40  fami_tieneinternet             626339 non-null  int64
#  41  percentil_c_naturales          626339 non-null  int64
#  42  percentil_global               626339 non-null  int64
#  43  percentil_ingles               626339 non-null  int64
#  44  percentil_lectura_critica      626339 non-null  int64
#  45  percentil_matematicas          626339 non-null  int64
#  46  percentil_sociales_ciudadanas  626339 non-null  int64
#  47  punt_c_naturales               626339 non-null  int64
#  48  punt_global                    626339 non-null  int64
#  49  punt_ingles                    626339 non-null  int64
#  50  punt_lectura_critica           626339 non-null  int64
#  51  punt_matematicas               626339 non-null  int64
#  52  punt_sociales_ciudadanas       626339 non-null  int64
# dtypes: float64(3), int64(22), object(28)
# memory usage: 253.3+ MB
# None

# %%
cols_drop = [
    "cole_genero",
    "cole_jornada",
    "cole_caracter",
    "estu_genero",
    "estu_grado",
    "estu_dedicacioninternet",  
    "estu_dedicacionlecturadiaria",
    "estu_horassemanatrabaja",
    "fami_comecarnepescadohuevo",
    "fami_comecerealfrutoslegumbre",
    "fami_comelechederivados",
    "fami_cuartoshogar",
    "fami_educacionmadre",
    "fami_educacionpadre",
    "fami_numlibros",
    "fami_personashogar",
    "fami_tienecomputador",
    "fami_tieneinternet"
]


print("Columnas antes:", len(df_icfes_2024.columns))

df_icfes_2024.drop(columns=cols_drop, inplace=True)

print("Columnas eliminadas:", len(cols_drop))
print("Columnas después:", len(df_icfes_2024.columns))
# Out:
# Columnas antes: 53
# Columnas eliminadas: 18
# Columnas después: 35

# %%
print(df_icfes_2024.head(15).to_string())
# Out:
#     periodo estu_estudiante cole_area_ubicacion  cole_bilingue cole_calendario cole_depto_ubicacion cole_mcpio_ubicacion cole_naturaleza  desemp_c_naturales desemp_ingles  desemp_lectura_critica  desemp_matematicas  desemp_sociales_ciudadanas estu_depto_presentacion estu_depto_reside  estu_inse_individual estu_mcpio_presentacion estu_mcpio_reside estu_nacionalidad  estu_nse_establecimiento  estu_nse_individual estu_pais_reside  fami_estratovivienda  percentil_c_naturales  percentil_global  percentil_ingles  percentil_lectura_critica  percentil_matematicas  percentil_sociales_ciudadanas  punt_c_naturales  punt_global  punt_ingles  punt_lectura_critica  punt_matematicas  punt_sociales_ciudadanas
# 0     20241      ESTUDIANTE              URBANO              1               B               BOGOTÁ          BOGOTÁ D.C.      NO OFICIAL                   3            B+                       4                   3                           4                  BOGOTÁ            BOGOTÁ             81.453896             BOGOTÁ D.C.       BOGOTÁ D.C.          COLOMBIA                       4.0                  4.0         COLOMBIA                     4                     71                79                89                         78                     66                             91                64          344           84                    69                65                        72
# 1     20241      ESTUDIANTE              URBANO              1               A               BOGOTÁ          BOGOTÁ D.C.      NO OFICIAL                   2            A-                       3                   3                           2                  BOGOTÁ            BOGOTÁ             55.711433             BOGOTÁ D.C.       BOGOTÁ D.C.          COLOMBIA                       3.0                  3.0         COLOMBIA                     4                     22                32                23                         45                     47                             24                43          250           47                    58                57                        43
# 2     20241      ESTUDIANTE              URBANO              1               B               BOGOTÁ          BOGOTÁ D.C.      NO OFICIAL                   2            A2                       2                   2                           1                  BOGOTÁ            BOGOTÁ             61.920422             BOGOTÁ D.C.       BOGOTÁ D.C.          COLOMBIA                       3.0                  3.0         COLOMBIA                     2                     42                23                44                         23                     19                              6                53          229           61                    49                43                        33
# 3     20241      ESTUDIANTE              URBANO              0               B                VALLE                 CALI      NO OFICIAL                   3            A2                       3                   3                           3                   VALLE             VALLE             63.934669                    CALI              CALI          COLOMBIA                       3.0                  3.0         COLOMBIA                     3                     68                48                51                         28                     39                             57                63          286           66                    51                53                        59
# 4     20241      ESTUDIANTE              URBANO              1               B               BOGOTÁ          BOGOTÁ D.C.      NO OFICIAL                   2            B1                       3                   3                           3                  BOGOTÁ            BOGOTÁ             70.367226             BOGOTÁ D.C.       BOGOTÁ D.C.          COLOMBIA                       3.0                  4.0         COLOMBIA                     3                     48                47                63                         46                     36                             50                55          285           74                    59                52                        56
# 5     20241      ESTUDIANTE              URBANO              0               B              QUINDIO              ARMENIA      NO OFICIAL                   4            B1                       4                   4                           4                 QUINDIO           QUINDIO             65.811295                 ARMENIA           ARMENIA          COLOMBIA                       4.0                  4.0         COLOMBIA                     4                     99                96                64                        100                     88                             93                78          382           75                    81                74                        73
# 6     20241      ESTUDIANTE               RURAL              0               B         CUNDINAMARCA               CAJICÁ      NO OFICIAL                   4            B+                       4                   4                           4            CUNDINAMARCA      CUNDINAMARCA             68.626114               ZIPAQUIRÁ            CAJICÁ          COLOMBIA                       4.0                  4.0         COLOMBIA                     4                     93                97                94                         97                     95                             96                72          384           87                    77                79                        76
# 7     20241      ESTUDIANTE              URBANO              1            OTRO               BOGOTÁ          BOGOTÁ D.C.      NO OFICIAL                   2            A1                       3                   2                           2                  BOGOTÁ            BOGOTÁ             70.812935             BOGOTÁ D.C.       BOGOTÁ D.C.          COLOMBIA                       3.0                  4.0         COLOMBIA                     4                     26                25                24                         29                     20                             31                45          234           48                    52                43                        47
# 8     20241      ESTUDIANTE              URBANO              1            OTRO               BOGOTÁ          BOGOTÁ D.C.      NO OFICIAL                   3            B+                       4                   4                           4                  BOGOTÁ            BOGOTÁ             65.021194             BOGOTÁ D.C.       BOGOTÁ D.C.          COLOMBIA                       3.0                  4.0         COLOMBIA                     5                     74                93               100                         92                     86                             96                65          371          100                    74                73                        76
# 9     20241      ESTUDIANTE              URBANO              1               B            ANTIOQUIA             ENVIGADO      NO OFICIAL                   4            B+                       4                   4                           4               ANTIOQUIA         ANTIOQUIA             86.107559                ENVIGADO          ENVIGADO          COLOMBIA                       4.0                  4.0         COLOMBIA                     6                    100               100               100                         98                     87                             90               100          412          100                    78                74                        72
# 10    20241      ESTUDIANTE              URBANO              1            OTRO               BOGOTÁ          BOGOTÁ D.C.      NO OFICIAL                   2            A2                       3                   2                           3                  BOGOTÁ            BOGOTÁ             64.478317             BOGOTÁ D.C.       BOGOTÁ D.C.          COLOMBIA                       3.0                  4.0         COLOMBIA                     3                     32                37                52                         40                     22                             49                48          262           67                    57                44                        56
# 11    20241      ESTUDIANTE              URBANO              1            OTRO               BOGOTÁ          BOGOTÁ D.C.      NO OFICIAL                   3            B+                       4                   3                           3                  BOGOTÁ            BOGOTÁ             61.110371             BOGOTÁ D.C.       BOGOTÁ D.C.          COLOMBIA                       3.0                  3.0         COLOMBIA                     3                     85                73               100                         75                     51                             60                69          334          100                    68                59                        60
# 12    20241      ESTUDIANTE              URBANO              1               B               BOGOTÁ          BOGOTÁ D.C.      NO OFICIAL                   2            B+                       3                   3                           3                  BOGOTÁ            BOGOTÁ             81.588676             BOGOTÁ D.C.       BOGOTÁ D.C.          COLOMBIA                       4.0                  4.0         COLOMBIA                     6                     44                60               100                         51                     64                             53                53          310          100                    61                64                        57
# 13    20241      ESTUDIANTE              URBANO              1               A               BOGOTÁ          BOGOTÁ D.C.      NO OFICIAL                   4            B+                       4                   4                           4                  BOGOTÁ            BOGOTÁ             70.024185             BOGOTÁ D.C.       BOGOTÁ D.C.          COLOMBIA                       3.0                  4.0         COLOMBIA                     4                     96               100                87                        100                    100                             96                74          418           84                   100                84                        76
# 14    20241      ESTUDIANTE               RURAL              1               B                VALLE                YUMBO      NO OFICIAL                   4            B+                       4                   4                           3                   VALLE             VALLE             76.013123                    CALI              CALI          COLOMBIA                       4.0                  4.0         COLOMBIA                     5                     93                97               100                         98                    100                             87                72          388          100                    78                83                        70

# %%
cols_dep_mun = [
    "cole_depto_ubicacion",
    "cole_mcpio_ubicacion",
    "estu_depto_presentacion",
    "estu_depto_reside",
    "estu_mcpio_presentacion",
    "estu_mcpio_reside"
]

for col in cols_dep_mun:
    print(f"\nValores únicos en {col}:")
    print(df_icfes_2024[col].unique())
# Out:
# Valores únicos en cole_depto_ubicacion:
# ['BOGOTÁ' 'VALLE' 'QUINDIO' 'CUNDINAMARCA' 'ANTIOQUIA' 'BOLIVAR' 'CAUCA'
#  'ATLANTICO' 'NARIÑO' 'SANTANDER' 'CORDOBA' 'RISARALDA' 'CESAR'
#  'MAGDALENA' 'HUILA' 'CALDAS' 'NORTE SANTANDER' 'TOLIMA' 'LA GUAJIRA'
#  'META' 'CASANARE' 'ARAUCA' 'SUCRE' 'BOYACA' 'CAQUETA' 'PUTUMAYO'
#  'GUAVIARE' 'CHOCO' 'GUAINIA' 'DESCONOCIDO' 'VICHADA' 'AMAZONAS'
#  'SAN ANDRES' 'VAUPES']
#
# Valores únicos en cole_mcpio_ubicacion:
# ['BOGOTÁ D.C.' 'CALI' 'ARMENIA' ... 'UNIÓN PANAMERICANA' 'RECETOR'
#  'BARRANCO MINAS']
#
# Valores únicos en estu_depto_presentacion:
# ['BOGOTÁ' 'VALLE' 'QUINDIO' 'CUNDINAMARCA' 'ANTIOQUIA' 'BOLIVAR' 'CAUCA'
#  'ATLANTICO' 'TOLIMA' 'SANTANDER' 'CORDOBA' 'RISARALDA' 'CESAR'
#  'MAGDALENA' 'HUILA' 'NARIÑO' 'CALDAS' 'NORTE SANTANDER' 'LA GUAJIRA'
#  'META' 'ARAUCA' 'SUCRE' 'CAQUETA' 'CASANARE' 'BOYACA' 'SAN ANDRES'
#  'PUTUMAYO' 'GUAVIARE' 'CHOCO' 'AMAZONAS' 'VAUPES' 'GUAINIA' 'VICHADA']
#
# Valores únicos en estu_depto_reside:
# ['BOGOTÁ' 'VALLE' 'QUINDIO' 'CUNDINAMARCA' 'ANTIOQUIA' 'BOLIVAR' 'CAUCA'
#  'ATLANTICO' 'NARIÑO' 'SANTANDER' 'CORDOBA' 'RISARALDA' 'CESAR'
#  'MAGDALENA' 'HUILA' 'CALDAS' 'NORTE SANTANDER' 'TOLIMA' 'LA GUAJIRA'
#  'META' 'ARAUCA' 'SUCRE' 'CASANARE' 'BOYACA' 'CAQUETA' 'SAN ANDRES'
#  'PUTUMAYO' 'GUAVIARE' 'CHOCO' 'AMAZONAS' 'GUAINIA' 'VICHADA' 'VAUPES'
#  'EXTRANJERO']
#
# Valores únicos en estu_mcpio_presentacion:
# ['BOGOTÁ D.C.' 'CALI' 'ARMENIA' 'ZIPAQUIRÁ' 'ENVIGADO' 'PALMIRA'
#  'CARTAGENA DE INDIAS' 'POPAYÁN' 'GUADALAJARA DE BUGA' 'BARRANQUILLA'
#  'IBAGUÉ' 'FACATATIVÁ' 'BUCARAMANGA' 'MONTERÍA' 'PEREIRA' 'VALLEDUPAR'
#  'PIEDECUESTA' 'SANTA MARTA' 'PITALITO' 'MEDELLÍN' 'RIONEGRO' 'IPIALES'
#  'MANIZALES' 'SOACHA' 'CÚCUTA' 'CARTAGO' 'PASTO' 'ESPINAL' 'AGUACHICA'
#  'OCAÑA' 'MAICAO' 'VILLAVICENCIO' 'SAN ANDRÉS DE TUMACO' 'MONTELÍBANO'
#  'BUENAVENTURA' 'ARAUCA' 'SINCELEJO' 'GIRARDOT' 'TULUÁ' 'NEIVA' 'ITAGÜÍ'
#  'PATÍA' 'FLORENCIA' 'YOPAL' 'SOGAMOSO' 'GRANADA' 'MAGANGUÉ' 'ROLDANILLO'
#  'TUNJA' 'SAN ANDRÉS' 'SANTANDER DE QUILICHAO' 'TÚQUERRES' 'MOCOA'
#  'BARRANCABERMEJA' 'TIBÚ' 'APARTADÓ' 'FUSAGASUGÁ' 'BARBOSA' 'ALBANIA'
#  'SAN JOSÉ DEL GUAVIARE' 'PUERTO ASÍS' 'ORITO' 'TAME' 'PAMPLONA'
#  'LA DORADA' 'QUIBDÓ' 'LÉRIDA' 'LETICIA' 'EL DONCELLO' 'CAUCASIA'
#  'EL PAUJÍL' 'SAN GIL' 'MITÚ' 'LA PLATA' 'SARAVENA' 'RIOHACHA' 'INÍRIDA'
#  'CHÍA' 'VILLA DE LEYVA' 'SIBUNDOY' 'PUERTO CARREÑO' 'MESETAS' 'GIRARDOTA'
#  'SONSÓN' 'PAZ DE ARIPORO' 'NUQUÍ' 'TURBACO' 'MÁLAGA' 'SEVILLA' 'ISTMINA'
#  'LOS PATIOS' 'MONTENEGRO' 'TABIO' 'CHOCONTÁ' 'MIRANDA' 'ACACÍAS' 'URIBIA'
#  'FUNDACIÓN' 'SAN ALBERTO' 'TURBO' 'SABANALARGA' 'DOSQUEBRADAS' 'SALAZAR'
#  'PEÑOL' 'CALARCÁ' 'CHAPARRAL' 'BELLO' 'FUNZA' 'MOGOTES' 'SANTA ROSALÍA'
#  'LA CEJA' 'ACEVEDO' 'OLAYA HERRERA' 'VILLA DEL ROSARIO' 'MONIQUIRÁ'
#  'GUARNE' 'SAN SEBASTIÁN DE BUENAVISTA' 'CÁCHIRA' 'SAN PELAYO'
#  'PUERTO TRIUNFO' 'FLORIDABLANCA' 'LORICA' 'GIRÓN' 'CHIGORODÓ' 'MAJAGUAL'
#  'CÁCERES' 'PARATEBUENO' 'VILLANUEVA' 'COPACABANA' 'FONSECA' 'MOSQUERA'
#  'SABANA DE TORRES' 'NECOCLÍ' 'SANTA ANA' 'PAIPA' 'QUINCHÍA' 'VEGACHÍ'
#  'SANTO TOMÁS' 'SAN PEDRO DE URABÁ' 'ROVIRA' 'LA JAGUA DE IBIRICO'
#  'TAURAMENA' 'ÁBREGO' 'VALENCIA' 'CIÉNAGA' 'ANDALUCÍA' 'DUITAMA'
#  'PUERTO GUZMÁN' 'LA UNIÓN' 'AYAPEL' 'CHARALÁ' 'CORINTO' 'MADRID'
#  'BUENAVISTA' 'SOLEDAD' 'ZARAGOZA' 'LA VEGA' 'NOCAIMA' 'PENSILVANIA'
#  'YARUMAL' 'PUERTO SANTANDER' 'ASTREA' 'MANÍ' 'CAJICÁ' 'AIPE' 'SOCORRO'
#  'SALAMINA' 'CHIQUINQUIRÁ' 'FRONTINO' 'BOAVITA' 'MARSELLA' 'CALOTO'
#  'PUERTO BERRÍO' 'ARJONA' 'RIOSUCIO' 'VILLETA' 'MIRAFLORES' 'YOLOMBÓ'
#  'ZARZAL' 'LA PAZ' 'CANDELARIA' 'EL TAMBO' 'REMEDIOS' 'HATONUEVO'
#  'MALAMBO' 'SAMANIEGO' 'MANZANARES' 'YUMBO' 'CIÉNAGA DE ORO' 'SOPETRÁN'
#  'SAN MARCOS' 'MARÍA LA BAJA' 'ANDES' 'SAN ESTANISLAO' 'MARQUETALIA'
#  'SAN JUAN DEL CESAR' 'LA ESTRELLA' 'EL CARMEN DE VIBORAL' 'EL SANTUARIO'
#  'SUBACHOQUE' 'URRAO' 'GIGANTE' 'SAN JUAN DE RIOSECO' 'SAN PEDRO' 'PLATO'
#  'ISNOS' 'VILLA DE SAN DIEGO DE UBATÉ' 'PALERMO' 'CIUDAD BOLÍVAR'
#  'CÁQUEZA' 'NATAGAIMA' 'TIMANÁ' 'FLORIDA' 'EL BANCO' 'MOMPÓS' 'JAMUNDÍ'
#  'GARAGOA' 'PUERTO TEJADA' 'SANTA FÉ DE ANTIOQUIA' 'URIBE'
#  'CAMPO DE LA CRUZ' 'JERICÓ' 'PLANETA RICA' 'BARANOA' 'LA VIRGINIA'
#  'ITUANGO' 'CERETÉ' 'SILVANIA' 'INZÁ' 'BARBACOAS' 'CIRCASIA' 'CAREPA'
#  'PACHO' 'VILLAGARZÓN' 'CALDAS' 'SAN LUIS DE GACENO' 'BALBOA' 'FRESNO'
#  'SANTIAGO DE TOLÚ' 'EL COCUY' 'CUMARIBO' 'PELAYA'
#  'SAN ANDRÉS DE SOTAVENTO' 'TIERRALTA' 'SAN JOSÉ DEL FRAGUA' 'SAHAGÚN'
#  'CHINÁCOTA' 'TRUJILLO' 'REPELÓN' 'ALBÁN' 'GUAPÍ' 'ARBOLEDAS' 'SEGOVIA'
#  'BUESACO' 'SAN CARLOS' 'BARRANCAS' 'SAN PABLO' 'EL CERRITO' 'CHINÚ'
#  'GARZÓN' 'PUERTO RICO' 'GUACARÍ' 'BELALCÁZAR' 'SAN JUAN DE URABÁ'
#  'LA MESA' 'SAN BENITO ABAD' 'SAMACÁ' 'PIVIJAY' 'SABANETA' 'EL COLEGIO'
#  'CAICEDONIA' 'SABANAGRANDE' 'SAN MARTÍN' 'EL TABLÓN DE GÓMEZ'
#  'SAN SEBASTIÁN DE MARIQUITA' 'EL TARRA' 'ANSERMA' 'VALLE DEL GUAMUEZ'
#  'GALERAS' 'EL BAGRE' 'MARINILLA' 'SAN ONOFRE' 'CIMITARRA' 'CISNEROS'
#  'SAN VICENTE DE CHUCURÍ' 'LA TEBAIDA' 'ARBOLETES' 'LA MACARENA'
#  'PINILLOS' 'SAN AGUSTÍN' 'TAMINANGO' 'ANOLAIMA' 'EL CHARCO'
#  'BELÉN DE UMBRÍA' 'MELGAR' 'GUAMO' 'DAGUA' 'COROZAL' 'ALCALÁ' 'VÉLEZ'
#  'CRAVO NORTE' 'BECERRIL' 'SANDONÁ' 'SANTA ROSA DEL SUR' 'FÓMEQUE'
#  'COVEÑAS' 'CHIVOLO' 'MEDINA' 'PUERTO LEGUÍZAMO' 'ACHÍ' 'HONDA' 'FALAN'
#  'BOSCONIA' 'VENTAQUEMADA' 'SANTA ROSA DE OSOS' 'RIVERA'
#  'PIENDAMÓ - TUNÍA' 'PUERTO NARIÑO' 'SAN JUAN NEPOMUCENO' 'MOÑITOS'
#  'SAN VICENTE DEL CAGUÁN' 'CONTRATACIÓN' 'LEBRIJA' 'CURUMANÍ' 'EL PASO'
#  'CAMPOALEGRE' 'ARACATACA' 'CHIMICHAGUA' 'AMAGÁ' 'PÁEZ' 'SOATÁ'
#  'EL RETORNO' 'SAN PEDRO DE LOS MILAGROS' 'AGUADAS' 'ZAPATOCA' 'OVEJAS'
#  'SANTA ROSA DE CABAL' 'NECHÍ' 'SAN BERNARDO DEL VIENTO' 'SANTA BÁRBARA'
#  'SIMITÍ' 'MANAURE' 'BARRANCO DE LOBA' 'URUMITA' 'TÁMESIS' 'ANORÍ'
#  'CAJAMARCA' 'VIOTÁ' 'GUADUAS' 'FRANCISCO PIZARRO' 'TOLEDO'
#  'PUERTO GAITÁN' 'SUCRE' 'REMOLINO' 'SILVIA' 'AGUSTÍN CODAZZI' 'CUMBAL'
#  'ARIGUANÍ' 'MATANZA' 'APÍA' 'SIBATÉ' 'BOLÍVAR' 'EL CARMEN DE BOLÍVAR'
#  'COYAIMA' 'LÍBANO' 'CHINCHINÁ' 'CAÑASGORDAS' 'PÁCORA' 'VISTAHERMOSA'
#  'SAN MARTÍN DE LOBA' 'AGUAZUL' 'SUÁREZ' 'GUAMAL' 'ICONONZO' 'MUTATÁ'
#  'SAN ROQUE' 'ZONA BANANERA' 'UNE' 'CALAMAR' 'PUENTE NACIONAL'
#  'CARTAGENA DEL CHAIRÁ' 'QUIMBAYA' 'PUERTO LÓPEZ' 'TURMEQUÉ' 'DABEIBA'
#  'EL PIÑÓN' 'SANTA MARÍA' 'GÓMEZ PLATA' 'MONTECRISTO' 'RAMIRIQUÍ'
#  'VALPARAÍSO' 'GUACHUCAL' 'SARDINATA' 'CHITA' 'LA PALMA' 'FREDONIA'
#  'LÓPEZ DE MICAY' 'ARAUQUITA' 'DIBULLA' 'CÓMBITA' 'LA CRUZ'
#  'PUERTO LIBERTADOR' 'RESTREPO' 'VENADILLO' 'RÍO VIEJO' 'ANSERMANUEVO'
#  'PUERTO BOYACÁ' 'MERCADERES' 'SOCHA' 'LA PEDRERA' 'OTANCHE' 'NEIRA'
#  'GINEBRA' 'CONSACÁ' 'PRADERA' 'CUMARAL' 'AMALFI' 'GACHETÁ' 'LA TOLA'
#  'ATACO' 'PURIFICACIÓN' 'SIMIJACA' 'EL PLAYÓN' 'LA CALERA' 'MORALES'
#  'PEQUE' 'MUZO' 'CAPITANEJO' 'EL COPEY' 'TIMBIQUÍ' 'TOCAIMA' 'ANAPOIMA'
#  'PUERTO CONCORDIA' 'PLANADAS' 'CONVENCIÓN' 'TAMALAMEQUE' 'TENERIFE'
#  'CARMEN DE APICALÁ' 'VIGÍA DEL FUERTE' 'SITIONUEVO' 'PROVIDENCIA'
#  'CARURÚ' 'PUERTO WILCHES' 'MANATÍ' 'SAN LUIS DE SINCÉ' 'RICAURTE'
#  'EL ÁGUILA' 'SAN LUIS DE PALENQUE' 'PUPIALES' 'CALIMA' 'SANTO DOMINGO'
#  'SAN JACINTO' 'LEIVA' 'OROCUÉ' 'GACHALÁ' 'EL CARMEN DE CHUCURÍ'
#  'ARBELÁEZ' 'EL CAIRO' 'GUATEQUE' 'BUENOS AIRES' 'DONMATÍAS'
#  'SANTA ROSA DE VITERBO' 'UNGUÍA' 'ALMAGUER' 'TANGUA' 'CHIRIGUANÁ'
#  'MIRITÍ - PARANÁ' 'CAPARRAPÍ' 'MONTERREY' 'ATRATO' 'LA ARGENTINA'
#  'BAHÍA SOLANO' 'NUNCHÍA' 'EL CARMEN DE ATRATO' 'LEJANÍAS' 'BOJAYÁ'
#  'SANTUARIO' 'ARMERO' 'MAGÜÍ' 'ACANDÍ' 'SAMANÁ' 'PUEBLO BELLO' 'ARENAL'
#  'MACEO' 'TUTA' 'MAPIRIPÁN' 'PIJAO' 'ABEJORRAL' 'PACOA' 'LA PRIMAVERA'
#  'PAUNA' 'BUGALAGRANDE' 'TÁMARA' 'TORO' 'CUCUTILLA' 'SOLITA' 'YAVARATÉ'
#  'PEDRAZA' 'GÜICÁN DE LA SIERRA' 'CARMEN DEL DARIÉN' 'LA MERCED'
#  'TRINIDAD' 'PUERTO ARICA' 'TARAIRA' 'JURADÓ' 'DOLORES' 'SAN FELIPE'
#  'HATO COROZAL' 'GUACHENÉ' 'EL ENCANTO' 'LA CHORRERA' 'BARRANCO MINAS'
#  'MAPIRIPANA']
#
# Valores únicos en estu_mcpio_reside:
# ['BOGOTÁ D.C.' 'CALI' 'ARMENIA' ... 'RECETOR' 'BARRANCO MINAS' 'NÓVITA']

# %%
map_deptos = {
    "BOGOTÁ": "BOGOTÁ, D.C.",
    "BOGOTA": "BOGOTÁ, D.C.",
    "BOGOTÁ D.C.": "BOGOTÁ, D.C.",
    "BOGOTA D.C.":"BOGOTÁ, D.C.",
    "VALLE": "VALLE DEL CAUCA",
    "QUINDIO": "QUINDÍO",
    "CUNDINAMARCA": "CUNDINAMARCA",
    "ANTIOQUIA": "ANTIOQUIA",
    "BOLIVAR": "BOLÍVAR",
    "CAUCA": "CAUCA",
    "ATLANTICO": "ATLÁNTICO",
    "NARIÑO": "NARIÑO",
    "NARINO": "NARIÑO",
    "SANTANDER": "SANTANDER",
    "CORDOBA": "CÓRDOBA",
    "RISARALDA": "RISARALDA",
    "CESAR": "CESAR",
    "MAGDALENA": "MAGDALENA",
    "HUILA": "HUILA",
    "CALDAS": "CALDAS",
    "NORTE SANTANDER": "NORTE DE SANTANDER",
    "NORTE DE SANTANDER": "NORTE DE SANTANDER",
    "TOLIMA": "TOLIMA",
    "LA GUAJIRA": "LA GUAJIRA",
    "META": "META",
    "CASANARE": "CASANARE",
    "ARAUCA": "ARAUCA",
    "SUCRE": "SUCRE",
    "BOYACA": "BOYACÁ",
    "CAQUETA": "CAQUETÁ",
    "PUTUMAYO": "PUTUMAYO",
    "GUAVIARE": "GUAVIARE",
    "CHOCO": "CHOCÓ",
    "GUAINIA": "GUAINÍA",
    "VICHADA": "VICHADA",
    "AMAZONAS": "AMAZONAS",
    "SAN ANDRES": "SAN ANDRÉS, PROVIDENCIA Y SANTA CATALINA",
    "SAN ANDRES Y PROVIDENCIA": "SAN ANDRÉS, PROVIDENCIA Y SANTA CATALINA",
    "VAUPES": "VAUPÉS",
    "VALLE": "VALLE DEL CAUCA",
    "VALLE DEL CAUCA": "VALLE DEL CAUCA",
    "DESCONOCIDO": "DESCONOCIDO",
    "EXTRANJERO": "EXTRANJERO"
}

# %%
map_mpios = {
    # --- Diferencias reales de escritura / nombre ---
    "ARMERO GUAYABAL": "ARMERO",
    "BOGOTA": "BOGOTA D.C.",
    "CALIMA EL DARIEN": "CALIMA",
    "CARTAGENA": "CARTAGENA DE INDIAS",
    "CHIBOLO": "CHIVOLO",
    "DON MATIAS": "DONMATIAS",
    "FUENTE DE ORO": "FUENTEDEORO",
    "GUICAN": "GUICAN DE LA SIERRA",
    "MAGUI PAYAN": "MAGUI",
    "MARIQUITA": "SAN SEBASTIAN DE MARIQUITA",
    "PIENDAMO": "PIENDAMO - TUNIA",
    "PURISIMA": "PURISIMA DE LA CONCEPCION",
    "SALAZAR DE LAS PALMAS": "SALAZAR",
    "SAN JOSE DEL PALMAR": "SAN JOSE DEL PALMAR",  
    "SAN JUAN DE RIO SECO": "SAN JUAN DE RIOSECO",
    "SAN VICENTE": "SAN VICENTE FERRER",
    "SANTA CRUZ DE LORICA": "LORICA",
    "SANTAFE DE ANTIOQUIA": "SANTA FE DE ANTIOQUIA",
    "SINCE": "SAN LUIS DE SINCE",
    "TUMACO": "SAN ANDRES DE TUMACO",
    "UBATE": "VILLA DE SAN DIEGO DE UBATE",


    # --- Municipios sin correspondencia directa (presentes solo en Población) ---
    "RIO IRO": None,
    "SIPI": None,

    # --- Municipios presentes solo en ICFES (sin equivalente en Población) ---
    # (referencia para ampliar catálogo si lo deseas)
    # "BARRANCO MINAS": None,
    # "CACAHUAL": None,
    # "EL ENCANTO": None,
    # "EXTRANJERO": None,
    # "GUACHENE": None,
    # "LA CHORRERA": None,
    # "LA PEDRERA": None,
    # "MIRITI - PARANA": None,
    # "NOROSI": None,
    # "PACOA": None,
    # "PUERTO ARICA": None,
    # "SAN ANDRES DE CUERQUIA": None,
    # "SAN FELIPE": None,
    # "SAN JOSE DE URE": None,
    # "SAN PEDRO DE LOS MILAGROS": None,
    # "MANAURE BALCON DEL CESAR": None,
    # "YAVARATE": None,
    # "BELEN DE BAJIRA": None # se cruza entre dos datasets que lo tienen en dos departamentes diferentes
}

# %%
# --- Normalizar departamentos ---
cols_deptos = ["cole_depto_ubicacion", "estu_depto_presentacion", "estu_depto_reside"]

for col in cols_deptos:
    df_icfes_2024[col] = df_icfes_2024[col].str.upper().replace(map_deptos)


print(df_icfes_2024[["cole_depto_ubicacion"]].head(50))
# Out:
#    cole_depto_ubicacion
# 0          BOGOTÁ, D.C.
# 1          BOGOTÁ, D.C.
# 2          BOGOTÁ, D.C.
# 3       VALLE DEL CAUCA
# 4          BOGOTÁ, D.C.
# 5               QUINDÍO
# 6          CUNDINAMARCA
# 7          BOGOTÁ, D.C.
# 8          BOGOTÁ, D.C.
# 9             ANTIOQUIA
# 10         BOGOTÁ, D.C.
# 11         BOGOTÁ, D.C.
# 12         BOGOTÁ, D.C.
# 13         BOGOTÁ, D.C.
# 14      VALLE DEL CAUCA
# 15         BOGOTÁ, D.C.
# 16      VALLE DEL CAUCA
# 17         BOGOTÁ, D.C.
# 18      VALLE DEL CAUCA
# 19      VALLE DEL CAUCA
# 20              BOLÍVAR
# 21                CAUCA
# 22         BOGOTÁ, D.C.
# 23         BOGOTÁ, D.C.
# 24      VALLE DEL CAUCA
# 25         BOGOTÁ, D.C.
# 26      VALLE DEL CAUCA
# 27         CUNDINAMARCA
# 28         CUNDINAMARCA
# 29      VALLE DEL CAUCA
# 30      VALLE DEL CAUCA
# 31      VALLE DEL CAUCA
# 32      VALLE DEL CAUCA
# 33      VALLE DEL CAUCA
# 34         BOGOTÁ, D.C.
# 35         BOGOTÁ, D.C.
# 36      VALLE DEL CAUCA
# 37      VALLE DEL CAUCA
# 38            ATLÁNTICO
# 39               NARIÑO
# 40         CUNDINAMARCA
# 41      VALLE DEL CAUCA
# 42         BOGOTÁ, D.C.
# 43         CUNDINAMARCA
# 44            SANTANDER
# 45              CÓRDOBA
# 46              BOLÍVAR
# 47            RISARALDA
# 48      VALLE DEL CAUCA
# 49            SANTANDER

# %%
bloque_ubicacion = [
    "cole_depto_ubicacion", "cole_mcpio_ubicacion",
    "estu_depto_presentacion", "estu_mcpio_presentacion",
    "estu_depto_reside", "estu_mcpio_reside",
    "estu_nacionalidad", "estu_pais_reside"
]

bloque_socioeco = [
    "estu_inse_individual", "estu_nse_individual",
    "estu_nse_establecimiento", "fami_estratovivienda"
]

# Columnas fijas iniciales (antes de ubicación)
inicio = ["periodo", "estu_estudiante", "cole_area_ubicacion", 
            "cole_bilingue", "cole_calendario", "cole_naturaleza"]

# Columnas que no entran en ubicación ni socioeconómico
otras = [col for col in df_icfes_2024.columns 
            if col not in inicio + bloque_ubicacion + bloque_socioeco]

# Orden final
orden_columnas = inicio + bloque_ubicacion + bloque_socioeco + otras


if "punt_global" in orden_columnas:
    orden_columnas.remove("punt_global")
    orden_columnas.append("punt_global")

# Reordenar el DataFrame
df_icfes_2024 = df_icfes_2024[orden_columnas]

print(df_icfes_2024.head(25).to_string())
# Out:
#     periodo estu_estudiante cole_area_ubicacion  cole_bilingue cole_calendario cole_naturaleza cole_depto_ubicacion cole_mcpio_ubicacion estu_depto_presentacion estu_mcpio_presentacion estu_depto_reside    estu_mcpio_reside estu_nacionalidad estu_pais_reside  estu_inse_individual  estu_nse_individual  estu_nse_establecimiento  fami_estratovivienda  desemp_c_naturales desemp_ingles  desemp_lectura_critica  desemp_matematicas  desemp_sociales_ciudadanas  percentil_c_naturales  percentil_global  percentil_ingles  percentil_lectura_critica  percentil_matematicas  percentil_sociales_ciudadanas  punt_c_naturales  punt_ingles  punt_lectura_critica  punt_matematicas  punt_sociales_ciudadanas  punt_global
# 0     20241      ESTUDIANTE              URBANO              1               B      NO OFICIAL         BOGOTÁ, D.C.          BOGOTÁ D.C.            BOGOTÁ, D.C.             BOGOTÁ D.C.      BOGOTÁ, D.C.          BOGOTÁ D.C.          COLOMBIA         COLOMBIA             81.453896                  4.0                       4.0                     4                   3            B+                       4                   3                           4                     71                79                89                         78                     66                             91                64           84                    69                65                        72          344
# 1     20241      ESTUDIANTE              URBANO              1               A      NO OFICIAL         BOGOTÁ, D.C.          BOGOTÁ D.C.            BOGOTÁ, D.C.             BOGOTÁ D.C.      BOGOTÁ, D.C.          BOGOTÁ D.C.          COLOMBIA         COLOMBIA             55.711433                  3.0                       3.0                     4                   2            A-                       3                   3                           2                     22                32                23                         45                     47                             24                43           47                    58                57                        43          250
# 2     20241      ESTUDIANTE              URBANO              1               B      NO OFICIAL         BOGOTÁ, D.C.          BOGOTÁ D.C.            BOGOTÁ, D.C.             BOGOTÁ D.C.      BOGOTÁ, D.C.          BOGOTÁ D.C.          COLOMBIA         COLOMBIA             61.920422                  3.0                       3.0                     2                   2            A2                       2                   2                           1                     42                23                44                         23                     19                              6                53           61                    49                43                        33          229
# 3     20241      ESTUDIANTE              URBANO              0               B      NO OFICIAL      VALLE DEL CAUCA                 CALI         VALLE DEL CAUCA                    CALI   VALLE DEL CAUCA                 CALI          COLOMBIA         COLOMBIA             63.934669                  3.0                       3.0                     3                   3            A2                       3                   3                           3                     68                48                51                         28                     39                             57                63           66                    51                53                        59          286
# 4     20241      ESTUDIANTE              URBANO              1               B      NO OFICIAL         BOGOTÁ, D.C.          BOGOTÁ D.C.            BOGOTÁ, D.C.             BOGOTÁ D.C.      BOGOTÁ, D.C.          BOGOTÁ D.C.          COLOMBIA         COLOMBIA             70.367226                  4.0                       3.0                     3                   2            B1                       3                   3                           3                     48                47                63                         46                     36                             50                55           74                    59                52                        56          285
# 5     20241      ESTUDIANTE              URBANO              0               B      NO OFICIAL              QUINDÍO              ARMENIA                 QUINDÍO                 ARMENIA           QUINDÍO              ARMENIA          COLOMBIA         COLOMBIA             65.811295                  4.0                       4.0                     4                   4            B1                       4                   4                           4                     99                96                64                        100                     88                             93                78           75                    81                74                        73          382
# 6     20241      ESTUDIANTE               RURAL              0               B      NO OFICIAL         CUNDINAMARCA               CAJICÁ            CUNDINAMARCA               ZIPAQUIRÁ      CUNDINAMARCA               CAJICÁ          COLOMBIA         COLOMBIA             68.626114                  4.0                       4.0                     4                   4            B+                       4                   4                           4                     93                97                94                         97                     95                             96                72           87                    77                79                        76          384
# 7     20241      ESTUDIANTE              URBANO              1            OTRO      NO OFICIAL         BOGOTÁ, D.C.          BOGOTÁ D.C.            BOGOTÁ, D.C.             BOGOTÁ D.C.      BOGOTÁ, D.C.          BOGOTÁ D.C.          COLOMBIA         COLOMBIA             70.812935                  4.0                       3.0                     4                   2            A1                       3                   2                           2                     26                25                24                         29                     20                             31                45           48                    52                43                        47          234
# 8     20241      ESTUDIANTE              URBANO              1            OTRO      NO OFICIAL         BOGOTÁ, D.C.          BOGOTÁ D.C.            BOGOTÁ, D.C.             BOGOTÁ D.C.      BOGOTÁ, D.C.          BOGOTÁ D.C.          COLOMBIA         COLOMBIA             65.021194                  4.0                       3.0                     5                   3            B+                       4                   4                           4                     74                93               100                         92                     86                             96                65          100                    74                73                        76          371
# 9     20241      ESTUDIANTE              URBANO              1               B      NO OFICIAL            ANTIOQUIA             ENVIGADO               ANTIOQUIA                ENVIGADO         ANTIOQUIA             ENVIGADO          COLOMBIA         COLOMBIA             86.107559                  4.0                       4.0                     6                   4            B+                       4                   4                           4                    100               100               100                         98                     87                             90               100          100                    78                74                        72          412
# 10    20241      ESTUDIANTE              URBANO              1            OTRO      NO OFICIAL         BOGOTÁ, D.C.          BOGOTÁ D.C.            BOGOTÁ, D.C.             BOGOTÁ D.C.      BOGOTÁ, D.C.          BOGOTÁ D.C.          COLOMBIA         COLOMBIA             64.478317                  4.0                       3.0                     3                   2            A2                       3                   2                           3                     32                37                52                         40                     22                             49                48           67                    57                44                        56          262
# 11    20241      ESTUDIANTE              URBANO              1            OTRO      NO OFICIAL         BOGOTÁ, D.C.          BOGOTÁ D.C.            BOGOTÁ, D.C.             BOGOTÁ D.C.      BOGOTÁ, D.C.          BOGOTÁ D.C.          COLOMBIA         COLOMBIA             61.110371                  3.0                       3.0                     3                   3            B+                       4                   3                           3                     85                73               100                         75                     51                             60                69          100                    68                59                        60          334
# 12    20241      ESTUDIANTE              URBANO              1               B      NO OFICIAL         BOGOTÁ, D.C.          BOGOTÁ D.C.            BOGOTÁ, D.C.             BOGOTÁ D.C.      BOGOTÁ, D.C.          BOGOTÁ D.C.          COLOMBIA         COLOMBIA             81.588676                  4.0                       4.0                     6                   2            B+                       3                   3                           3                     44                60               100                         51                     64                             53                53          100                    61                64                        57          310
# 13    20241      ESTUDIANTE              URBANO              1               A      NO OFICIAL         BOGOTÁ, D.C.          BOGOTÁ D.C.            BOGOTÁ, D.C.             BOGOTÁ D.C.      BOGOTÁ, D.C.          BOGOTÁ D.C.          COLOMBIA         COLOMBIA             70.024185                  4.0                       3.0                     4                   4            B+                       4                   4                           4                     96               100                87                        100                    100                             96                74           84                   100                84                        76          418
# 14    20241      ESTUDIANTE               RURAL              1               B      NO OFICIAL      VALLE DEL CAUCA                YUMBO         VALLE DEL CAUCA                    CALI   VALLE DEL CAUCA                 CALI          COLOMBIA         COLOMBIA             76.013123                  4.0                       4.0                     5                   4            B+                       4                   4                           3                     93                97               100                         98                    100                             87                72          100                    78                83                        70          388
# 15    20241      ESTUDIANTE              URBANO              0               A      NO OFICIAL         BOGOTÁ, D.C.          BOGOTÁ D.C.            BOGOTÁ, D.C.             BOGOTÁ D.C.      BOGOTÁ, D.C.          BOGOTÁ D.C.          COLOMBIA         COLOMBIA             75.759224                  4.0                       4.0                     5                   3            B+                       4                   4                           3                     84                84                74                         88                     91                             68                68           79                    72                76                        63          352
# 16    20241      ESTUDIANTE              URBANO              0               B      NO OFICIAL      VALLE DEL CAUCA                 CALI         VALLE DEL CAUCA                    CALI   VALLE DEL CAUCA                 CALI          COLOMBIA         COLOMBIA             68.584991                  4.0                       4.0                     2                   3            B+                       4                   4                           3                     81                81                84                         80                     93                             62                67           83                    69                77                        61          348
# 17    20241      ESTUDIANTE              URBANO              1               B      NO OFICIAL         BOGOTÁ, D.C.          BOGOTÁ D.C.            BOGOTÁ, D.C.             BOGOTÁ D.C.      BOGOTÁ, D.C.          BOGOTÁ D.C.          COLOMBIA         COLOMBIA             73.038437                  4.0                       4.0                     6                   4            B+                       4                   4                           4                     97                99                88                         93                    100                             96                75           84                    75               100                        76          408
# 18    20241      ESTUDIANTE              URBANO              0               B      NO OFICIAL      VALLE DEL CAUCA                 CALI         VALLE DEL CAUCA                    CALI   VALLE DEL CAUCA                 CALI          COLOMBIA         COLOMBIA             54.377247                  3.0                       3.0                     3                   2            A1                       2                   2                           2                     28                24                35                         21                     20                             25                46           55                    48                44                        44          231
# 19    20241      ESTUDIANTE              URBANO              1               B      NO OFICIAL      VALLE DEL CAUCA              PALMIRA         VALLE DEL CAUCA                 PALMIRA   VALLE DEL CAUCA              PALMIRA          COLOMBIA         COLOMBIA             62.358109                  3.0                       3.0                     3                   3            B1                       4                   3                           4                     61                78                70                         81                     69                             95                60           78                    70                66                        75          343
# 20    20241      ESTUDIANTE               RURAL              0               A      NO OFICIAL              BOLÍVAR              TURBACO                 BOLÍVAR     CARTAGENA DE INDIAS           BOLÍVAR  CARTAGENA DE INDIAS          COLOMBIA         COLOMBIA             53.884212                  3.0                       3.0                     1                   1            A-                       1                   1                           1                      3                 2                 3                          3                      5                              2                33           31                    35                32                        29          161
# 21    20241      ESTUDIANTE              URBANO              0               B      NO OFICIAL                CAUCA              POPAYÁN                   CAUCA                 POPAYÁN             CAUCA              POPAYÁN          COLOMBIA         COLOMBIA             59.814934                  3.0                       3.0                     4                   3            A2                       4                   3                           3                     87                74                51                         76                     78                             60                70           66                    68                70                        60          335
# 22    20241      ESTUDIANTE              URBANO              1               B      NO OFICIAL         BOGOTÁ, D.C.          BOGOTÁ D.C.            BOGOTÁ, D.C.             BOGOTÁ D.C.      BOGOTÁ, D.C.          BOGOTÁ D.C.          COLOMBIA         COLOMBIA             79.294014                  4.0                       4.0                     5                   4            B+                       4                   4                           4                     94               100               100                         96                    100                            100                73          100                    77                84                       100          424
# 23    20241      ESTUDIANTE              URBANO              0               A      NO OFICIAL         BOGOTÁ, D.C.          BOGOTÁ D.C.            BOGOTÁ, D.C.             BOGOTÁ D.C.      BOGOTÁ, D.C.          BOGOTÁ D.C.          COLOMBIA         COLOMBIA             63.120708                  3.0                       3.0                     2                   1            A-                       1                   2                           1                      8                 9                22                          3                     13                             18                36           47                    35                38                        40          190
# 24    20241      ESTUDIANTE              URBANO              0               B      NO OFICIAL      VALLE DEL CAUCA                 CALI         VALLE DEL CAUCA                    CALI   VALLE DEL CAUCA                 CALI          COLOMBIA         COLOMBIA             72.571617                  4.0                       4.0                     5                   3            A2                       4                   3                           3                     69                62                52                         75                     53                             55                63           67                    68                60                        58          313

# %% [markdown]
# **Dataset Incidencia de Pobreza Monetaria 2024 DANE por Departamento**

# %%
FILE_DANE = "../data/staging/dane_pobreza_monetaria.csv"
df_pobreza_monetaria = pd.read_csv(FILE_DANE, encoding="utf-8")

print("Shape:", df_pobreza_monetaria.shape)
print(df_pobreza_monetaria.info())
print(df_pobreza_monetaria.head(24))
# Out:
# Shape: (24, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Departamento  24 non-null     object
#  1   Pobreza_2023  24 non-null     float64
#  2   Pobreza_2024  24 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 708.0+ bytes
# None
#           Departamento  Pobreza_2023  Pobreza_2024
# 0                Chocó          69.9          67.4
# 1           La Guajira          67.7          65.7
# 2                Sucre          58.1          57.5
# 3            Magdalena          50.3          51.7
# 4              Córdoba          53.9          49.6
# 5              Bolívar          49.7          48.0
# 6                Cesar          54.4          47.8
# 7                Cauca          47.0          43.1
# 8                Huila          40.2          40.4
# 9               Nariño          38.8          39.2
# 10             Caquetá          39.1          37.4
# 11              Tolima          39.6          35.6
# 12  Norte de Santander          38.8          35.3
# 13           Atlántico          31.3          31.6
# 14              Boyacá          32.8          30.9
# 15           Santander          30.9          27.4
# 16             Quindío          28.7          25.9
# 17     Valle del Cauca          27.8          25.7
# 18           Antioquia          27.5          24.7
# 19           Risaralda          28.2          23.8
# 20                Meta          27.7          23.6
# 21        Cundinamarca          22.4          20.1
# 22              Caldas          23.6          20.0
# 23         Bogotá D.C.          24.1          19.6

# %%
df_pobreza_monetaria.drop(columns=["Pobreza_2023"], inplace=True)

print("Shape después de eliminar:", df_pobreza_monetaria.shape)
print(df_pobreza_monetaria.head())
# Out:
# Shape después de eliminar: (24, 2)
#   Departamento  Pobreza_2024
# 0        Chocó          67.4
# 1   La Guajira          65.7
# 2        Sucre          57.5
# 3    Magdalena          51.7
# 4      Córdoba          49.6

# %%
#Normalización

df_pobreza_monetaria["Departamento"] = (
    df_pobreza_monetaria["Departamento"]
    .apply(lambda x: ''.join(
        c for c in unicodedata.normalize('NFD', str(x))
        if unicodedata.category(c) != 'Mn'
    ))
)

df_pobreza_monetaria["Departamento"] = df_pobreza_monetaria["Departamento"].str.upper()


df_pobreza_monetaria["Departamento"] = df_pobreza_monetaria["Departamento"].replace(map_deptos)


print(df_pobreza_monetaria.head(24))
# Out:
#           Departamento  Pobreza_2024
# 0                CHOCÓ          67.4
# 1           LA GUAJIRA          65.7
# 2                SUCRE          57.5
# 3            MAGDALENA          51.7
# 4              CÓRDOBA          49.6
# 5              BOLÍVAR          48.0
# 6                CESAR          47.8
# 7                CAUCA          43.1
# 8                HUILA          40.4
# 9               NARIÑO          39.2
# 10             CAQUETÁ          37.4
# 11              TOLIMA          35.6
# 12  NORTE DE SANTANDER          35.3
# 13           ATLÁNTICO          31.6
# 14              BOYACÁ          30.9
# 15           SANTANDER          27.4
# 16             QUINDÍO          25.9
# 17     VALLE DEL CAUCA          25.7
# 18           ANTIOQUIA          24.7
# 19           RISARALDA          23.8
# 20                META          23.6
# 21        CUNDINAMARCA          20.1
# 22              CALDAS          20.0
# 23        BOGOTÁ, D.C.          19.6

# %%
# Unir por departamento de residencia
df_icfes_2024 = df_icfes_2024.merge(
    df_pobreza_monetaria.rename(columns={"Pobreza_2024": "pobreza_monetaria_depto"}),
    how="left",
    left_on="estu_depto_reside",
    right_on="Departamento"
).drop(columns=["Departamento"])  # quitamos columna duplicada

# Reordenar columnas: meter pobreza_monetaria_depto después de estu_pais_reside
cols = df_icfes_2024.columns.tolist()
cols.remove("pobreza_monetaria_depto")   # quitarla temporalmente de la lista
idx = cols.index("estu_pais_reside") + 1
cols.insert(idx, "pobreza_monetaria_depto")  # insertarla en la posición deseada

df_icfes_2024 = df_icfes_2024[cols]

print(df_icfes_2024.head(15).to_string())
# Out:
#     periodo estu_estudiante cole_area_ubicacion  cole_bilingue cole_calendario cole_naturaleza cole_depto_ubicacion cole_mcpio_ubicacion estu_depto_presentacion estu_mcpio_presentacion estu_depto_reside estu_mcpio_reside estu_nacionalidad estu_pais_reside  pobreza_monetaria_depto  estu_inse_individual  estu_nse_individual  estu_nse_establecimiento  fami_estratovivienda  desemp_c_naturales desemp_ingles  desemp_lectura_critica  desemp_matematicas  desemp_sociales_ciudadanas  percentil_c_naturales  percentil_global  percentil_ingles  percentil_lectura_critica  percentil_matematicas  percentil_sociales_ciudadanas  punt_c_naturales  punt_ingles  punt_lectura_critica  punt_matematicas  punt_sociales_ciudadanas  punt_global
# 0     20241      ESTUDIANTE              URBANO              1               B      NO OFICIAL         BOGOTÁ, D.C.          BOGOTÁ D.C.            BOGOTÁ, D.C.             BOGOTÁ D.C.      BOGOTÁ, D.C.       BOGOTÁ D.C.          COLOMBIA         COLOMBIA                     19.6             81.453896                  4.0                       4.0                     4                   3            B+                       4                   3                           4                     71                79                89                         78                     66                             91                64           84                    69                65                        72          344
# 1     20241      ESTUDIANTE              URBANO              1               A      NO OFICIAL         BOGOTÁ, D.C.          BOGOTÁ D.C.            BOGOTÁ, D.C.             BOGOTÁ D.C.      BOGOTÁ, D.C.       BOGOTÁ D.C.          COLOMBIA         COLOMBIA                     19.6             55.711433                  3.0                       3.0                     4                   2            A-                       3                   3                           2                     22                32                23                         45                     47                             24                43           47                    58                57                        43          250
# 2     20241      ESTUDIANTE              URBANO              1               B      NO OFICIAL         BOGOTÁ, D.C.          BOGOTÁ D.C.            BOGOTÁ, D.C.             BOGOTÁ D.C.      BOGOTÁ, D.C.       BOGOTÁ D.C.          COLOMBIA         COLOMBIA                     19.6             61.920422                  3.0                       3.0                     2                   2            A2                       2                   2                           1                     42                23                44                         23                     19                              6                53           61                    49                43                        33          229
# 3     20241      ESTUDIANTE              URBANO              0               B      NO OFICIAL      VALLE DEL CAUCA                 CALI         VALLE DEL CAUCA                    CALI   VALLE DEL CAUCA              CALI          COLOMBIA         COLOMBIA                     25.7             63.934669                  3.0                       3.0                     3                   3            A2                       3                   3                           3                     68                48                51                         28                     39                             57                63           66                    51                53                        59          286
# 4     20241      ESTUDIANTE              URBANO              1               B      NO OFICIAL         BOGOTÁ, D.C.          BOGOTÁ D.C.            BOGOTÁ, D.C.             BOGOTÁ D.C.      BOGOTÁ, D.C.       BOGOTÁ D.C.          COLOMBIA         COLOMBIA                     19.6             70.367226                  4.0                       3.0                     3                   2            B1                       3                   3                           3                     48                47                63                         46                     36                             50                55           74                    59                52                        56          285
# 5     20241      ESTUDIANTE              URBANO              0               B      NO OFICIAL              QUINDÍO              ARMENIA                 QUINDÍO                 ARMENIA           QUINDÍO           ARMENIA          COLOMBIA         COLOMBIA                     25.9             65.811295                  4.0                       4.0                     4                   4            B1                       4                   4                           4                     99                96                64                        100                     88                             93                78           75                    81                74                        73          382
# 6     20241      ESTUDIANTE               RURAL              0               B      NO OFICIAL         CUNDINAMARCA               CAJICÁ            CUNDINAMARCA               ZIPAQUIRÁ      CUNDINAMARCA            CAJICÁ          COLOMBIA         COLOMBIA                     20.1             68.626114                  4.0                       4.0                     4                   4            B+                       4                   4                           4                     93                97                94                         97                     95                             96                72           87                    77                79                        76          384
# 7     20241      ESTUDIANTE              URBANO              1            OTRO      NO OFICIAL         BOGOTÁ, D.C.          BOGOTÁ D.C.            BOGOTÁ, D.C.             BOGOTÁ D.C.      BOGOTÁ, D.C.       BOGOTÁ D.C.          COLOMBIA         COLOMBIA                     19.6             70.812935                  4.0                       3.0                     4                   2            A1                       3                   2                           2                     26                25                24                         29                     20                             31                45           48                    52                43                        47          234
# 8     20241      ESTUDIANTE              URBANO              1            OTRO      NO OFICIAL         BOGOTÁ, D.C.          BOGOTÁ D.C.            BOGOTÁ, D.C.             BOGOTÁ D.C.      BOGOTÁ, D.C.       BOGOTÁ D.C.          COLOMBIA         COLOMBIA                     19.6             65.021194                  4.0                       3.0                     5                   3            B+                       4                   4                           4                     74                93               100                         92                     86                             96                65          100                    74                73                        76          371
# 9     20241      ESTUDIANTE              URBANO              1               B      NO OFICIAL            ANTIOQUIA             ENVIGADO               ANTIOQUIA                ENVIGADO         ANTIOQUIA          ENVIGADO          COLOMBIA         COLOMBIA                     24.7             86.107559                  4.0                       4.0                     6                   4            B+                       4                   4                           4                    100               100               100                         98                     87                             90               100          100                    78                74                        72          412
# 10    20241      ESTUDIANTE              URBANO              1            OTRO      NO OFICIAL         BOGOTÁ, D.C.          BOGOTÁ D.C.            BOGOTÁ, D.C.             BOGOTÁ D.C.      BOGOTÁ, D.C.       BOGOTÁ D.C.          COLOMBIA         COLOMBIA                     19.6             64.478317                  4.0                       3.0                     3                   2            A2                       3                   2                           3                     32                37                52                         40                     22                             49                48           67                    57                44                        56          262
# 11    20241      ESTUDIANTE              URBANO              1            OTRO      NO OFICIAL         BOGOTÁ, D.C.          BOGOTÁ D.C.            BOGOTÁ, D.C.             BOGOTÁ D.C.      BOGOTÁ, D.C.       BOGOTÁ D.C.          COLOMBIA         COLOMBIA                     19.6             61.110371                  3.0                       3.0                     3                   3            B+                       4                   3                           3                     85                73               100                         75                     51                             60                69          100                    68                59                        60          334
# 12    20241      ESTUDIANTE              URBANO              1               B      NO OFICIAL         BOGOTÁ, D.C.          BOGOTÁ D.C.            BOGOTÁ, D.C.             BOGOTÁ D.C.      BOGOTÁ, D.C.       BOGOTÁ D.C.          COLOMBIA         COLOMBIA                     19.6             81.588676                  4.0                       4.0                     6                   2            B+                       3                   3                           3                     44                60               100                         51                     64                             53                53          100                    61                64                        57          310
# 13    20241      ESTUDIANTE              URBANO              1               A      NO OFICIAL         BOGOTÁ, D.C.          BOGOTÁ D.C.            BOGOTÁ, D.C.             BOGOTÁ D.C.      BOGOTÁ, D.C.       BOGOTÁ D.C.          COLOMBIA         COLOMBIA                     19.6             70.024185                  4.0                       3.0                     4                   4            B+                       4                   4                           4                     96               100                87                        100                    100                             96                74           84                   100                84                        76          418
# 14    20241      ESTUDIANTE               RURAL              1               B      NO OFICIAL      VALLE DEL CAUCA                YUMBO         VALLE DEL CAUCA                    CALI   VALLE DEL CAUCA              CALI          COLOMBIA         COLOMBIA                     25.7             76.013123                  4.0                       4.0                     5                   4            B+                       4                   4                           3                     93                97               100                         98                    100                             87                72          100                    78                83                        70          388

# %% [markdown]
# **Dataset Índice de Desarrollo Humano (IDH) 2024**

# %%
FILE_IDH = "../data/staging/idh_departamentos.csv"
df_idh_departamentos = pd.read_csv(FILE_IDH, encoding="utf-8")

print("Shape:", df_idh_departamentos.shape)
print(df_idh_departamentos.info())
print(df_idh_departamentos.head(33))
# Out:
# Shape: (33, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Entidad    33 non-null     object
#  1   IDH        33 non-null     float64
#  2   Población  33 non-null     int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 924.0+ bytes
# None
#                      Entidad    IDH  Población
# 0                     Bogotá  0.890    7937898
# 1            Valle del Cauca  0.841    4652512
# 2   San Andrés y Providencia  0.837      62181
# 3                    Quindío  0.832     568560
# 4                     Caldas  0.828    1051282
# 5               Cundinamarca  0.826    3657407
# 6                       Meta  0.824    1160351
# 7                  Santander  0.821    2393214
# 8                  Atlántico  0.817    2845169
# 9                  Antioquia  0.813    6951825
# 10                 Risaralda  0.812     974639
# 11                    Boyacá  0.808    1324122
# 12                   Bolívar  0.803    2278770
# 13                    Tolima  0.797    1386826
# 14                  Guaviare  0.796     103237
# 15                  Casanare  0.791     481938
# 16                   Vichada  0.785     127467
# 17                     Sucre  0.784    1016826
# 18        Norte de Santander  0.778    1717992
# 19                    Arauca  0.771     320723
# 20                     Cesar  0.770    1414859
# 21                     Huila  0.767    1205318
# 22                 Magdalena  0.767    1529038
# 23                    Nariño  0.763    1719281
# 24                     Cauca  0.760    1590171
# 25                  Amazonas  0.758      87480
# 26                  Putumayo  0.758     393988
# 27                   Caquetá  0.753     430884
# 28                   Córdoba  0.751    1929336
# 29                La Guajira  0.732    1073081
# 30                     Chocó  0.721     615082
# 31                   Guainía  0.702      59240
# 32                    Vaupés  0.681      49142

# %%
# Normalización
df_idh_departamentos["Entidad"] = (
    df_idh_departamentos["Entidad"]
    .apply(lambda x: ''.join(
        c for c in unicodedata.normalize('NFD', str(x))
        if unicodedata.category(c) != 'Mn'
    ))
)

df_idh_departamentos["Entidad"] = df_idh_departamentos["Entidad"].str.upper()

df_idh_departamentos["Entidad"] = df_idh_departamentos["Entidad"].replace(map_deptos)

print(df_idh_departamentos.head(33))
# Out:
#                                      Entidad    IDH  Población
# 0                               BOGOTÁ, D.C.  0.890    7937898
# 1                            VALLE DEL CAUCA  0.841    4652512
# 2   SAN ANDRÉS, PROVIDENCIA Y SANTA CATALINA  0.837      62181
# 3                                    QUINDÍO  0.832     568560
# 4                                     CALDAS  0.828    1051282
# 5                               CUNDINAMARCA  0.826    3657407
# 6                                       META  0.824    1160351
# 7                                  SANTANDER  0.821    2393214
# 8                                  ATLÁNTICO  0.817    2845169
# 9                                  ANTIOQUIA  0.813    6951825
# 10                                 RISARALDA  0.812     974639
# 11                                    BOYACÁ  0.808    1324122
# 12                                   BOLÍVAR  0.803    2278770
# 13                                    TOLIMA  0.797    1386826
# 14                                  GUAVIARE  0.796     103237
# 15                                  CASANARE  0.791     481938
# 16                                   VICHADA  0.785     127467
# 17                                     SUCRE  0.784    1016826
# 18                        NORTE DE SANTANDER  0.778    1717992
# 19                                    ARAUCA  0.771     320723
# 20                                     CESAR  0.770    1414859
# 21                                     HUILA  0.767    1205318
# 22                                 MAGDALENA  0.767    1529038
# 23                                    NARIÑO  0.763    1719281
# 24                                     CAUCA  0.760    1590171
# 25                                  AMAZONAS  0.758      87480
# 26                                  PUTUMAYO  0.758     393988
# 27                                   CAQUETÁ  0.753     430884
# 28                                   CÓRDOBA  0.751    1929336
# 29                                LA GUAJIRA  0.732    1073081
# 30                                     CHOCÓ  0.721     615082
# 31                                   GUAINÍA  0.702      59240
# 32                                    VAUPÉS  0.681      49142

# %%
# Unir de una sola vez con IDH y Población  por departamento de residencia
df_icfes_2024 = df_icfes_2024.merge(
    df_idh_departamentos.rename(columns={
        "IDH": "idh_depto",
        "Población": "poblacion_depto"
    }),
    how="left",
    left_on="estu_depto_reside",
    right_on="Entidad"
).drop(columns=["Entidad"])  # quitamos columna duplicada


# Reordenar columnas
cols = df_icfes_2024.columns.tolist()

# 1. Mover idh_depto después de estu_pais_reside
cols.remove("idh_depto")
idx = cols.index("estu_pais_reside") + 1
cols.insert(idx, "idh_depto")

# 2. Mover poblacion_depto después de estu_mcpio_reside
cols.remove("poblacion_depto")
idx = cols.index("estu_mcpio_reside") + 1
cols.insert(idx, "poblacion_depto")

df_icfes_2024 = df_icfes_2024[cols]

print(df_icfes_2024.head(15).to_string())
# Out:
#     periodo estu_estudiante cole_area_ubicacion  cole_bilingue cole_calendario cole_naturaleza cole_depto_ubicacion cole_mcpio_ubicacion estu_depto_presentacion estu_mcpio_presentacion estu_depto_reside estu_mcpio_reside  poblacion_depto estu_nacionalidad estu_pais_reside  idh_depto  pobreza_monetaria_depto  estu_inse_individual  estu_nse_individual  estu_nse_establecimiento  fami_estratovivienda  desemp_c_naturales desemp_ingles  desemp_lectura_critica  desemp_matematicas  desemp_sociales_ciudadanas  percentil_c_naturales  percentil_global  percentil_ingles  percentil_lectura_critica  percentil_matematicas  percentil_sociales_ciudadanas  punt_c_naturales  punt_ingles  punt_lectura_critica  punt_matematicas  punt_sociales_ciudadanas  punt_global
# 0     20241      ESTUDIANTE              URBANO              1               B      NO OFICIAL         BOGOTÁ, D.C.          BOGOTÁ D.C.            BOGOTÁ, D.C.             BOGOTÁ D.C.      BOGOTÁ, D.C.       BOGOTÁ D.C.        7937898.0          COLOMBIA         COLOMBIA      0.890                     19.6             81.453896                  4.0                       4.0                     4                   3            B+                       4                   3                           4                     71                79                89                         78                     66                             91                64           84                    69                65                        72          344
# 1     20241      ESTUDIANTE              URBANO              1               A      NO OFICIAL         BOGOTÁ, D.C.          BOGOTÁ D.C.            BOGOTÁ, D.C.             BOGOTÁ D.C.      BOGOTÁ, D.C.       BOGOTÁ D.C.        7937898.0          COLOMBIA         COLOMBIA      0.890                     19.6             55.711433                  3.0                       3.0                     4                   2            A-                       3                   3                           2                     22                32                23                         45                     47                             24                43           47                    58                57                        43          250
# 2     20241      ESTUDIANTE              URBANO              1               B      NO OFICIAL         BOGOTÁ, D.C.          BOGOTÁ D.C.            BOGOTÁ, D.C.             BOGOTÁ D.C.      BOGOTÁ, D.C.       BOGOTÁ D.C.        7937898.0          COLOMBIA         COLOMBIA      0.890                     19.6             61.920422                  3.0                       3.0                     2                   2            A2                       2                   2                           1                     42                23                44                         23                     19                              6                53           61                    49                43                        33          229
# 3     20241      ESTUDIANTE              URBANO              0               B      NO OFICIAL      VALLE DEL CAUCA                 CALI         VALLE DEL CAUCA                    CALI   VALLE DEL CAUCA              CALI        4652512.0          COLOMBIA         COLOMBIA      0.841                     25.7             63.934669                  3.0                       3.0                     3                   3            A2                       3                   3                           3                     68                48                51                         28                     39                             57                63           66                    51                53                        59          286
# 4     20241      ESTUDIANTE              URBANO              1               B      NO OFICIAL         BOGOTÁ, D.C.          BOGOTÁ D.C.            BOGOTÁ, D.C.             BOGOTÁ D.C.      BOGOTÁ, D.C.       BOGOTÁ D.C.        7937898.0          COLOMBIA         COLOMBIA      0.890                     19.6             70.367226                  4.0                       3.0                     3                   2            B1                       3                   3                           3                     48                47                63                         46                     36                             50                55           74                    59                52                        56          285
# 5     20241      ESTUDIANTE              URBANO              0               B      NO OFICIAL              QUINDÍO              ARMENIA                 QUINDÍO                 ARMENIA           QUINDÍO           ARMENIA         568560.0          COLOMBIA         COLOMBIA      0.832                     25.9             65.811295                  4.0                       4.0                     4                   4            B1                       4                   4                           4                     99                96                64                        100                     88                             93                78           75                    81                74                        73          382
# 6     20241      ESTUDIANTE               RURAL              0               B      NO OFICIAL         CUNDINAMARCA               CAJICÁ            CUNDINAMARCA               ZIPAQUIRÁ      CUNDINAMARCA            CAJICÁ        3657407.0          COLOMBIA         COLOMBIA      0.826                     20.1             68.626114                  4.0                       4.0                     4                   4            B+                       4                   4                           4                     93                97                94                         97                     95                             96                72           87                    77                79                        76          384
# 7     20241      ESTUDIANTE              URBANO              1            OTRO      NO OFICIAL         BOGOTÁ, D.C.          BOGOTÁ D.C.            BOGOTÁ, D.C.             BOGOTÁ D.C.      BOGOTÁ, D.C.       BOGOTÁ D.C.        7937898.0          COLOMBIA         COLOMBIA      0.890                     19.6             70.812935                  4.0                       3.0                     4                   2            A1                       3                   2                           2                     26                25                24                         29                     20                             31                45           48                    52                43                        47          234
# 8     20241      ESTUDIANTE              URBANO              1            OTRO      NO OFICIAL         BOGOTÁ, D.C.          BOGOTÁ D.C.            BOGOTÁ, D.C.             BOGOTÁ D.C.      BOGOTÁ, D.C.       BOGOTÁ D.C.        7937898.0          COLOMBIA         COLOMBIA      0.890                     19.6             65.021194                  4.0                       3.0                     5                   3            B+                       4                   4                           4                     74                93               100                         92                     86                             96                65          100                    74                73                        76          371
# 9     20241      ESTUDIANTE              URBANO              1               B      NO OFICIAL            ANTIOQUIA             ENVIGADO               ANTIOQUIA                ENVIGADO         ANTIOQUIA          ENVIGADO        6951825.0          COLOMBIA         COLOMBIA      0.813                     24.7             86.107559                  4.0                       4.0                     6                   4            B+                       4                   4                           4                    100               100               100                         98                     87                             90               100          100                    78                74                        72          412
# 10    20241      ESTUDIANTE              URBANO              1            OTRO      NO OFICIAL         BOGOTÁ, D.C.          BOGOTÁ D.C.            BOGOTÁ, D.C.             BOGOTÁ D.C.      BOGOTÁ, D.C.       BOGOTÁ D.C.        7937898.0          COLOMBIA         COLOMBIA      0.890                     19.6             64.478317                  4.0                       3.0                     3                   2            A2                       3                   2                           3                     32                37                52                         40                     22                             49                48           67                    57                44                        56          262
# 11    20241      ESTUDIANTE              URBANO              1            OTRO      NO OFICIAL         BOGOTÁ, D.C.          BOGOTÁ D.C.            BOGOTÁ, D.C.             BOGOTÁ D.C.      BOGOTÁ, D.C.       BOGOTÁ D.C.        7937898.0          COLOMBIA         COLOMBIA      0.890                     19.6             61.110371                  3.0                       3.0                     3                   3            B+                       4                   3                           3                     85                73               100                         75                     51                             60                69          100                    68                59                        60          334
# 12    20241      ESTUDIANTE              URBANO              1               B      NO OFICIAL         BOGOTÁ, D.C.          BOGOTÁ D.C.            BOGOTÁ, D.C.             BOGOTÁ D.C.      BOGOTÁ, D.C.       BOGOTÁ D.C.        7937898.0          COLOMBIA         COLOMBIA      0.890                     19.6             81.588676                  4.0                       4.0                     6                   2            B+                       3                   3                           3                     44                60               100                         51                     64                             53                53          100                    61                64                        57          310
# 13    20241      ESTUDIANTE              URBANO              1               A      NO OFICIAL         BOGOTÁ, D.C.          BOGOTÁ D.C.            BOGOTÁ, D.C.             BOGOTÁ D.C.      BOGOTÁ, D.C.       BOGOTÁ D.C.        7937898.0          COLOMBIA         COLOMBIA      0.890                     19.6             70.024185                  4.0                       3.0                     4                   4            B+                       4                   4                           4                     96               100                87                        100                    100                             96                74           84                   100                84                        76          418
# 14    20241      ESTUDIANTE               RURAL              1               B      NO OFICIAL      VALLE DEL CAUCA                YUMBO         VALLE DEL CAUCA                    CALI   VALLE DEL CAUCA              CALI        4652512.0          COLOMBIA         COLOMBIA      0.841                     25.7             76.013123                  4.0                       4.0                     5                   4            B+                       4                   4                           3                     93                97               100                         98                    100                             87                72          100                    78                83                        70          388

# %% [markdown]
# **Dataset Población por Municipios (1100 registros 1016 municipios)**

# %%
FILE_POBLACION_MUN = "../data/staging/poblacion_municipios.csv"
df_poblacion_municipios = pd.read_csv(FILE_POBLACION_MUN, encoding="utf-8")

print("Shape:", df_poblacion_municipios.shape)
print(df_poblacion_municipios.info())
print(df_poblacion_municipios.head(24))
# Out:
# Shape: (1100, 4)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Departamento  1100 non-null   object
#  1   Municipio     1100 non-null   object
#  2   URL           1100 non-null   object
#  3   Poblacion     1100 non-null   object
# dtypes: object(4)
# memory usage: 34.5+ KB
# None
#    Departamento        Municipio  \
# 0      Amazonas          Leticia
# 1      Amazonas    Puerto Nariño
# 2     Antioquia        Abejorral
# 3     Antioquia         Abriaquí
# 4     Antioquia       Alejandría
# 5     Antioquia            Amagá
# 6     Antioquia           Amalfi
# 7     Antioquia            Andes
# 8     Antioquia      Angelópolis
# 9     Antioquia        Angostura
# 10    Antioquia            Anorí
# 11    Antioquia             Anza
# 12    Antioquia         Apartadó
# 13    Antioquia        Arboletes
# 14    Antioquia          Argelia
# 15    Antioquia          Armenia
# 16    Antioquia          Barbosa
# 17    Antioquia  Belén De Bajirá
# 18    Antioquia            Bello
# 19    Antioquia          Belmira
# 20    Antioquia          Betania
# 21    Antioquia          Betulia
# 22    Antioquia          Briceño
# 23    Antioquia         Buriticá
#
#                                                   URL          Poblacion
# 0      https://www.municipios.com.co/amazonas/leticia   Población 32.450
# 1   https://www.municipios.com.co/amazonas/puerto-...    Población 6.816
# 2   https://www.municipios.com.co/antioquia/abejorral   Población 19.893
# 3    https://www.municipios.com.co/antioquia/abriaqui    Población 2.173
# 4   https://www.municipios.com.co/antioquia/alejan...    Población 3.730
# 5       https://www.municipios.com.co/antioquia/amaga   Población 27.115
# 6      https://www.municipios.com.co/antioquia/amalfi   Población 20.302
# 7       https://www.municipios.com.co/antioquia/andes   Población 41.491
# 8   https://www.municipios.com.co/antioquia/angelo...    Población 7.648
# 9   https://www.municipios.com.co/antioquia/angostura   Población 12.371
# 10      https://www.municipios.com.co/antioquia/anori    Población 9.638
# 11       https://www.municipios.com.co/antioquia/anza    Población 7.371
# 12   https://www.municipios.com.co/antioquia/apartado  Población 134.572
# 13  https://www.municipios.com.co/antioquia/arboletes   Población 31.039
# 14    https://www.municipios.com.co/antioquia/argelia    Población 6.823
# 15    https://www.municipios.com.co/antioquia/armenia    Población 5.096
# 16    https://www.municipios.com.co/antioquia/barbosa   Población 42.547
# 17  https://www.municipios.com.co/antioquia/belen-...    Población 5.583
# 18      https://www.municipios.com.co/antioquia/bello  Población 373.013
# 19    https://www.municipios.com.co/antioquia/belmira    Población 6.196
# 20    https://www.municipios.com.co/antioquia/betania   Población 10.120
# 21    https://www.municipios.com.co/antioquia/betulia   Población 16.665
# 22    https://www.municipios.com.co/antioquia/briceno    Población 7.953
# 23   https://www.municipios.com.co/antioquia/buritica    Población 6.472

# %%
df_poblacion_municipios = df_poblacion_municipios.drop(columns=["URL"])


df_poblacion_municipios["Poblacion"] = (
    df_poblacion_municipios["Poblacion"]
    .str.replace("Población", "", regex=False) 
    .str.replace(".", "", regex=False)          
    .str.strip()                               
    .astype(int)                                
)

print("Shape después de limpieza:", df_poblacion_municipios.shape)
print(df_poblacion_municipios.info())
print(df_poblacion_municipios.head(24))
# Out:
# Shape después de limpieza: (1100, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Departamento  1100 non-null   object
#  1   Municipio     1100 non-null   object
#  2   Poblacion     1100 non-null   int32
# dtypes: int32(1), object(2)
# memory usage: 21.6+ KB
# None
#    Departamento        Municipio  Poblacion
# 0      Amazonas          Leticia      32450
# 1      Amazonas    Puerto Nariño       6816
# 2     Antioquia        Abejorral      19893
# 3     Antioquia         Abriaquí       2173
# 4     Antioquia       Alejandría       3730
# 5     Antioquia            Amagá      27115
# 6     Antioquia           Amalfi      20302
# 7     Antioquia            Andes      41491
# 8     Antioquia      Angelópolis       7648
# 9     Antioquia        Angostura      12371
# 10    Antioquia            Anorí       9638
# 11    Antioquia             Anza       7371
# 12    Antioquia         Apartadó     134572
# 13    Antioquia        Arboletes      31039
# 14    Antioquia          Argelia       6823
# 15    Antioquia          Armenia       5096
# 16    Antioquia          Barbosa      42547
# 17    Antioquia  Belén De Bajirá       5583
# 18    Antioquia            Bello     373013
# 19    Antioquia          Belmira       6196
# 20    Antioquia          Betania      10120
# 21    Antioquia          Betulia      16665
# 22    Antioquia          Briceño       7953
# 23    Antioquia         Buriticá       6472

# %%
# Normalización 1


# --- 1. Función de normalización ---
def normalizar(s):
    if pd.isna(s):
        return ""
    s = str(s).upper().strip()
    s = ''.join(c for c in unicodedata.normalize('NFD', s) if unicodedata.category(c) != 'Mn')
    return s

# --- 2. Alinear índices antes de aplicar normalización ---
df_icfes_2024 = df_icfes_2024.reset_index(drop=True)
df_poblacion_municipios = df_poblacion_municipios.reset_index(drop=True)

# --- 3. Normalizar columnas de ICFES ---
df_icfes_2024["estu_mcpio_reside"] = df_icfes_2024["estu_mcpio_reside"].apply(normalizar)
df_icfes_2024["cole_mcpio_ubicacion"] = df_icfes_2024["cole_mcpio_ubicacion"].apply(normalizar)
df_icfes_2024["estu_mcpio_presentacion"] = df_icfes_2024["estu_mcpio_presentacion"].apply(normalizar)

# --- 4. Normalizar columnas de Población ---
df_poblacion_municipios["Municipio_norm"] = df_poblacion_municipios["Municipio"].apply(normalizar)

# --- 5. Aplicar mapeo sobre la columna normalizada de población ---
df_poblacion_municipios["Municipio_mapeado"] = (
    df_poblacion_municipios["Municipio_norm"]
    .replace(map_mpios)
    .fillna(df_poblacion_municipios["Municipio_norm"])
)

# --- 6. Verificación extendida ---
print("\n--- Verificación general del dataset de municipios ---")

filas_antes = df_poblacion_municipios.shape[0]
filas_despues = df_poblacion_municipios["Municipio_mapeado"].shape[0]
municipios_unicos_reales = df_poblacion_municipios["Municipio_mapeado"].nunique()

# Municipios que se repiten en más de un departamento
duplicados = df_poblacion_municipios["Municipio_mapeado"].value_counts().gt(1)
municipios_repetidos = duplicados.sum()
filas_repetidas = df_poblacion_municipios["Municipio_mapeado"].duplicated().sum()

# Filas afectadas por el mapeo
filas_afectadas = (
    df_poblacion_municipios["Municipio_norm"] !=
    df_poblacion_municipios["Municipio_mapeado"]
).sum()

# --- Resultados ---
print(f"Filas totales ANTES del mapeo: {filas_antes}")
print(f"Filas totales DESPUÉS del mapeo: {filas_despues}")
print(f"Municipios distintos (sin repetir por depto): {municipios_unicos_reales}")  # Aqui faltan 2 porque son los del mapeo que no tiene equivalencia
print(f"Municipios con nombre repetido en otros deptos: {municipios_repetidos}")
print(f"Filas que corresponden a esos municipios repetidos: {filas_repetidas}")
print(f"Filas modificadas por el mapeo: {filas_afectadas}")

print("\nEjemplo de normalización y mapeo aplicado:")
print(df_poblacion_municipios[["Departamento", "Municipio", "Municipio_norm", "Municipio_mapeado"]].head(15))
# Out:
# --- Verificación general del dataset de municipios ---
# Filas totales ANTES del mapeo: 1100
# Filas totales DESPUÉS del mapeo: 1100
# Municipios distintos (sin repetir por depto): 1014
# Municipios con nombre repetido en otros deptos: 66
# Filas que corresponden a esos municipios repetidos: 86
# Filas modificadas por el mapeo: 20
#
# Ejemplo de normalización y mapeo aplicado:
#    Departamento      Municipio Municipio_norm Municipio_mapeado
# 0      Amazonas        Leticia        LETICIA           LETICIA
# 1      Amazonas  Puerto Nariño  PUERTO NARINO     PUERTO NARINO
# 2     Antioquia      Abejorral      ABEJORRAL         ABEJORRAL
# 3     Antioquia       Abriaquí       ABRIAQUI          ABRIAQUI
# 4     Antioquia     Alejandría     ALEJANDRIA        ALEJANDRIA
# 5     Antioquia          Amagá          AMAGA             AMAGA
# 6     Antioquia         Amalfi         AMALFI            AMALFI
# 7     Antioquia          Andes          ANDES             ANDES
# 8     Antioquia    Angelópolis    ANGELOPOLIS       ANGELOPOLIS
# 9     Antioquia      Angostura      ANGOSTURA         ANGOSTURA
# 10    Antioquia          Anorí          ANORI             ANORI
# 11    Antioquia           Anza           ANZA              ANZA
# 12    Antioquia       Apartadó       APARTADO          APARTADO
# 13    Antioquia      Arboletes      ARBOLETES         ARBOLETES
# 14    Antioquia        Argelia        ARGELIA           ARGELIA

# %%
# Normalización 2

# --- 1. Normalización de Departamento ---
df_poblacion_municipios["Departamento_norm"] = df_poblacion_municipios["Departamento"].apply(normalizar)

# --- 2. Mapeo de Departamentos ---
df_poblacion_municipios["Departamento_mapeado"] = (
    df_poblacion_municipios["Departamento_norm"]
    .replace(map_deptos)
    .fillna(df_poblacion_municipios["Departamento_norm"])
)

# --- 3. Ajuste especial para Bogotá ---
# Si el municipio es "BOGOTA D.C." (ya normalizado y mapeado),
# se cambia el departamento a "BOGOTÁ, D.C."
mask_bogota = df_poblacion_municipios["Municipio_mapeado"] == "BOGOTA D.C."
df_poblacion_municipios.loc[mask_bogota, "Departamento_mapeado"] = "BOGOTÁ, D.C."

# --- 4. Verificación extendida ---
print("\n--- Verificación general del dataset de municipios ---")

# Totales antes y después (solo para control)
filas_antes = len(df_poblacion_municipios)
filas_despues = len(df_poblacion_municipios)

# Departamentos únicos antes y después
deptos_antes = df_poblacion_municipios["Departamento_norm"].nunique()
deptos_despues = df_poblacion_municipios["Departamento_mapeado"].nunique()

# Validar cuántas filas fueron afectadas por el ajuste especial
filas_bogota_cambiadas = mask_bogota.sum()

print(f"Filas totales ANTES: {filas_antes}")
print(f"Filas totales DESPUÉS: {filas_despues}")
print(f"Departamentos distintos ANTES: {deptos_antes}")
print(f"Departamentos distintos DESPUÉS: {deptos_despues}")
print(f"Filas modificadas por el ajuste especial del DC Bogotá: {filas_bogota_cambiadas}")

print("\nEjemplo de normalización y mapeo aplicado (primeras 15 filas):")
print(
    df_poblacion_municipios[
        ["Departamento", "Departamento_norm", "Departamento_mapeado", "Municipio_mapeado"]
    ].head(15)
)
# Out:
# --- Verificación general del dataset de municipios ---
# Filas totales ANTES: 1100
# Filas totales DESPUÉS: 1100
# Departamentos distintos ANTES: 32
# Departamentos distintos DESPUÉS: 33
# Filas modificadas por el ajuste especial del DC Bogotá: 1
#
# Ejemplo de normalización y mapeo aplicado (primeras 15 filas):
#    Departamento Departamento_norm Departamento_mapeado Municipio_mapeado
# 0      Amazonas          AMAZONAS             AMAZONAS           LETICIA
# 1      Amazonas          AMAZONAS             AMAZONAS     PUERTO NARINO
# 2     Antioquia         ANTIOQUIA            ANTIOQUIA         ABEJORRAL
# 3     Antioquia         ANTIOQUIA            ANTIOQUIA          ABRIAQUI
# 4     Antioquia         ANTIOQUIA            ANTIOQUIA        ALEJANDRIA
# 5     Antioquia         ANTIOQUIA            ANTIOQUIA             AMAGA
# 6     Antioquia         ANTIOQUIA            ANTIOQUIA            AMALFI
# 7     Antioquia         ANTIOQUIA            ANTIOQUIA             ANDES
# 8     Antioquia         ANTIOQUIA            ANTIOQUIA       ANGELOPOLIS
# 9     Antioquia         ANTIOQUIA            ANTIOQUIA         ANGOSTURA
# 10    Antioquia         ANTIOQUIA            ANTIOQUIA             ANORI
# 11    Antioquia         ANTIOQUIA            ANTIOQUIA              ANZA
# 12    Antioquia         ANTIOQUIA            ANTIOQUIA          APARTADO
# 13    Antioquia         ANTIOQUIA            ANTIOQUIA         ARBOLETES
# 14    Antioquia         ANTIOQUIA            ANTIOQUIA           ARGELIA

# %%
print("\nEjemplo final del dataset con mapeo aplicado:")
print(df_poblacion_municipios[["Departamento_mapeado", "Municipio_mapeado", "Poblacion"]].head(15))
# Out:
# Ejemplo final del dataset con mapeo aplicado:
#    Departamento_mapeado Municipio_mapeado  Poblacion
# 0              AMAZONAS           LETICIA      32450
# 1              AMAZONAS     PUERTO NARINO       6816
# 2             ANTIOQUIA         ABEJORRAL      19893
# 3             ANTIOQUIA          ABRIAQUI       2173
# 4             ANTIOQUIA        ALEJANDRIA       3730
# 5             ANTIOQUIA             AMAGA      27115
# 6             ANTIOQUIA            AMALFI      20302
# 7             ANTIOQUIA             ANDES      41491
# 8             ANTIOQUIA       ANGELOPOLIS       7648
# 9             ANTIOQUIA         ANGOSTURA      12371
# 10            ANTIOQUIA             ANORI       9638
# 11            ANTIOQUIA              ANZA       7371
# 12            ANTIOQUIA          APARTADO     134572
# 13            ANTIOQUIA         ARBOLETES      31039
# 14            ANTIOQUIA           ARGELIA       6823

# %%
# === Unir con población por municipio y departamento de residencia ===
df_icfes_2024 = df_icfes_2024.merge(
    df_poblacion_municipios.rename(columns={
        "Poblacion": "poblacion_mcpio"
    })[["Departamento_mapeado", "Municipio_mapeado", "poblacion_mcpio"]],
    how="left",
    left_on=["estu_depto_reside", "estu_mcpio_reside"],
    right_on=["Departamento_mapeado", "Municipio_mapeado"]
).drop(columns=["Departamento_mapeado", "Municipio_mapeado"], errors="ignore")

# --- Reordenar columnas ---
cols = df_icfes_2024.columns.tolist()
if "poblacion_mcpio" in cols and "poblacion_depto" in cols:
    cols.remove("poblacion_mcpio")
    idx = cols.index("poblacion_depto") + 1
    cols.insert(idx, "poblacion_mcpio")
    df_icfes_2024 = df_icfes_2024[cols]

# --- Verificación rápida ---
print("\nEjemplo de unión final con población por municipio:")
print(df_icfes_2024[["estu_depto_reside", "estu_mcpio_reside", "poblacion_depto", "poblacion_mcpio"]].head(15))

# --- Resumen del merge ---
total_filas = len(df_icfes_2024)
coincidencias = df_icfes_2024["poblacion_mcpio"].notna().sum()
sin_coincidencia = df_icfes_2024["poblacion_mcpio"].isna().sum()

print("\n--- Resumen de la unión ---")
print(f"Filas totales: {total_filas}")
print(f"Filas con coincidencia (población encontrada): {coincidencias}")
print(f"Filas sin coincidencia (población no encontrada): {sin_coincidencia}")
print(f"Porcentaje de éxito del merge: {coincidencias / total_filas * 100:.2f}%")
# Out:
# Ejemplo de unión final con población por municipio:
#    estu_depto_reside estu_mcpio_reside  poblacion_depto  poblacion_mcpio
# 0       BOGOTÁ, D.C.       BOGOTA D.C.        7937898.0        6778691.0
# 1       BOGOTÁ, D.C.       BOGOTA D.C.        7937898.0        6778691.0
# 2       BOGOTÁ, D.C.       BOGOTA D.C.        7937898.0        6778691.0
# 3    VALLE DEL CAUCA              CALI        4652512.0        2075380.0
# 4       BOGOTÁ, D.C.       BOGOTA D.C.        7937898.0        6778691.0
# 5            QUINDÍO           ARMENIA         568560.0         272574.0
# 6       CUNDINAMARCA            CAJICA        3657407.0          44721.0
# 7       BOGOTÁ, D.C.       BOGOTA D.C.        7937898.0        6778691.0
# 8       BOGOTÁ, D.C.       BOGOTA D.C.        7937898.0        6778691.0
# 9          ANTIOQUIA          ENVIGADO        6951825.0         175337.0
# 10      BOGOTÁ, D.C.       BOGOTA D.C.        7937898.0        6778691.0
# 11      BOGOTÁ, D.C.       BOGOTA D.C.        7937898.0        6778691.0
# 12      BOGOTÁ, D.C.       BOGOTA D.C.        7937898.0        6778691.0
# 13      BOGOTÁ, D.C.       BOGOTA D.C.        7937898.0        6778691.0
# 14   VALLE DEL CAUCA              CALI        4652512.0        2075380.0
#
# --- Resumen de la unión ---
# Filas totales: 626339
# Filas con coincidencia (población encontrada): 624839
# Filas sin coincidencia (población no encontrada): 1500
# Porcentaje de éxito del merge: 99.76%

# %%
print(df_icfes_2024.head(20).to_string())
# Out:
#     periodo estu_estudiante cole_area_ubicacion  cole_bilingue cole_calendario cole_naturaleza cole_depto_ubicacion cole_mcpio_ubicacion estu_depto_presentacion estu_mcpio_presentacion estu_depto_reside estu_mcpio_reside  poblacion_depto  poblacion_mcpio estu_nacionalidad estu_pais_reside  idh_depto  pobreza_monetaria_depto  estu_inse_individual  estu_nse_individual  estu_nse_establecimiento  fami_estratovivienda  desemp_c_naturales desemp_ingles  desemp_lectura_critica  desemp_matematicas  desemp_sociales_ciudadanas  percentil_c_naturales  percentil_global  percentil_ingles  percentil_lectura_critica  percentil_matematicas  percentil_sociales_ciudadanas  punt_c_naturales  punt_ingles  punt_lectura_critica  punt_matematicas  punt_sociales_ciudadanas  punt_global
# 0     20241      ESTUDIANTE              URBANO              1               B      NO OFICIAL         BOGOTÁ, D.C.          BOGOTA D.C.            BOGOTÁ, D.C.             BOGOTA D.C.      BOGOTÁ, D.C.       BOGOTA D.C.        7937898.0        6778691.0          COLOMBIA         COLOMBIA      0.890                     19.6             81.453896                  4.0                       4.0                     4                   3            B+                       4                   3                           4                     71                79                89                         78                     66                             91                64           84                    69                65                        72          344
# 1     20241      ESTUDIANTE              URBANO              1               A      NO OFICIAL         BOGOTÁ, D.C.          BOGOTA D.C.            BOGOTÁ, D.C.             BOGOTA D.C.      BOGOTÁ, D.C.       BOGOTA D.C.        7937898.0        6778691.0          COLOMBIA         COLOMBIA      0.890                     19.6             55.711433                  3.0                       3.0                     4                   2            A-                       3                   3                           2                     22                32                23                         45                     47                             24                43           47                    58                57                        43          250
# 2     20241      ESTUDIANTE              URBANO              1               B      NO OFICIAL         BOGOTÁ, D.C.          BOGOTA D.C.            BOGOTÁ, D.C.             BOGOTA D.C.      BOGOTÁ, D.C.       BOGOTA D.C.        7937898.0        6778691.0          COLOMBIA         COLOMBIA      0.890                     19.6             61.920422                  3.0                       3.0                     2                   2            A2                       2                   2                           1                     42                23                44                         23                     19                              6                53           61                    49                43                        33          229
# 3     20241      ESTUDIANTE              URBANO              0               B      NO OFICIAL      VALLE DEL CAUCA                 CALI         VALLE DEL CAUCA                    CALI   VALLE DEL CAUCA              CALI        4652512.0        2075380.0          COLOMBIA         COLOMBIA      0.841                     25.7             63.934669                  3.0                       3.0                     3                   3            A2                       3                   3                           3                     68                48                51                         28                     39                             57                63           66                    51                53                        59          286
# 4     20241      ESTUDIANTE              URBANO              1               B      NO OFICIAL         BOGOTÁ, D.C.          BOGOTA D.C.            BOGOTÁ, D.C.             BOGOTA D.C.      BOGOTÁ, D.C.       BOGOTA D.C.        7937898.0        6778691.0          COLOMBIA         COLOMBIA      0.890                     19.6             70.367226                  4.0                       3.0                     3                   2            B1                       3                   3                           3                     48                47                63                         46                     36                             50                55           74                    59                52                        56          285
# 5     20241      ESTUDIANTE              URBANO              0               B      NO OFICIAL              QUINDÍO              ARMENIA                 QUINDÍO                 ARMENIA           QUINDÍO           ARMENIA         568560.0         272574.0          COLOMBIA         COLOMBIA      0.832                     25.9             65.811295                  4.0                       4.0                     4                   4            B1                       4                   4                           4                     99                96                64                        100                     88                             93                78           75                    81                74                        73          382
# 6     20241      ESTUDIANTE               RURAL              0               B      NO OFICIAL         CUNDINAMARCA               CAJICA            CUNDINAMARCA               ZIPAQUIRA      CUNDINAMARCA            CAJICA        3657407.0          44721.0          COLOMBIA         COLOMBIA      0.826                     20.1             68.626114                  4.0                       4.0                     4                   4            B+                       4                   4                           4                     93                97                94                         97                     95                             96                72           87                    77                79                        76          384
# 7     20241      ESTUDIANTE              URBANO              1            OTRO      NO OFICIAL         BOGOTÁ, D.C.          BOGOTA D.C.            BOGOTÁ, D.C.             BOGOTA D.C.      BOGOTÁ, D.C.       BOGOTA D.C.        7937898.0        6778691.0          COLOMBIA         COLOMBIA      0.890                     19.6             70.812935                  4.0                       3.0                     4                   2            A1                       3                   2                           2                     26                25                24                         29                     20                             31                45           48                    52                43                        47          234
# 8     20241      ESTUDIANTE              URBANO              1            OTRO      NO OFICIAL         BOGOTÁ, D.C.          BOGOTA D.C.            BOGOTÁ, D.C.             BOGOTA D.C.      BOGOTÁ, D.C.       BOGOTA D.C.        7937898.0        6778691.0          COLOMBIA         COLOMBIA      0.890                     19.6             65.021194                  4.0                       3.0                     5                   3            B+                       4                   4                           4                     74                93               100                         92                     86                             96                65          100                    74                73                        76          371
# 9     20241      ESTUDIANTE              URBANO              1               B      NO OFICIAL            ANTIOQUIA             ENVIGADO               ANTIOQUIA                ENVIGADO         ANTIOQUIA          ENVIGADO        6951825.0         175337.0          COLOMBIA         COLOMBIA      0.813                     24.7             86.107559                  4.0                       4.0                     6                   4            B+                       4                   4                           4                    100               100               100                         98                     87                             90               100          100                    78                74                        72          412
# 10    20241      ESTUDIANTE              URBANO              1            OTRO      NO OFICIAL         BOGOTÁ, D.C.          BOGOTA D.C.            BOGOTÁ, D.C.             BOGOTA D.C.      BOGOTÁ, D.C.       BOGOTA D.C.        7937898.0        6778691.0          COLOMBIA         COLOMBIA      0.890                     19.6             64.478317                  4.0                       3.0                     3                   2            A2                       3                   2                           3                     32                37                52                         40                     22                             49                48           67                    57                44                        56          262
# 11    20241      ESTUDIANTE              URBANO              1            OTRO      NO OFICIAL         BOGOTÁ, D.C.          BOGOTA D.C.            BOGOTÁ, D.C.             BOGOTA D.C.      BOGOTÁ, D.C.       BOGOTA D.C.        7937898.0        6778691.0          COLOMBIA         COLOMBIA      0.890                     19.6             61.110371                  3.0                       3.0                     3                   3            B+                       4                   3                           3                     85                73               100                         75                     51                             60                69          100                    68                59                        60          334
# 12    20241      ESTUDIANTE              URBANO              1               B      NO OFICIAL         BOGOTÁ, D.C.          BOGOTA D.C.            BOGOTÁ, D.C.             BOGOTA D.C.      BOGOTÁ, D.C.       BOGOTA D.C.        7937898.0        6778691.0          COLOMBIA         COLOMBIA      0.890                     19.6             81.588676                  4.0                       4.0                     6                   2            B+                       3                   3                           3                     44                60               100                         51                     64                             53                53          100                    61                64                        57          310
# 13    20241      ESTUDIANTE              URBANO              1               A      NO OFICIAL         BOGOTÁ, D.C.          BOGOTA D.C.            BOGOTÁ, D.C.             BOGOTA D.C.      BOGOTÁ, D.C.       BOGOTA D.C.        7937898.0        6778691.0          COLOMBIA         COLOMBIA      0.890                     19.6             70.024185                  4.0                       3.0                     4                   4            B+                       4                   4                           4                     96               100                87                        100                    100                             96                74           84                   100                84                        76          418
# 14    20241      ESTUDIANTE               RURAL              1               B      NO OFICIAL      VALLE DEL CAUCA                YUMBO         VALLE DEL CAUCA                    CALI   VALLE DEL CAUCA              CALI        4652512.0        2075380.0          COLOMBIA         COLOMBIA      0.841                     25.7             76.013123                  4.0                       4.0                     5                   4            B+                       4                   4                           3                     93                97               100                         98                    100                             87                72          100                    78                83                        70          388
# 15    20241      ESTUDIANTE              URBANO              0               A      NO OFICIAL         BOGOTÁ, D.C.          BOGOTA D.C.            BOGOTÁ, D.C.             BOGOTA D.C.      BOGOTÁ, D.C.       BOGOTA D.C.        7937898.0        6778691.0          COLOMBIA         COLOMBIA      0.890                     19.6             75.759224                  4.0                       4.0                     5                   3            B+                       4                   4                           3                     84                84                74                         88                     91                             68                68           79                    72                76                        63          352
# 16    20241      ESTUDIANTE              URBANO              0               B      NO OFICIAL      VALLE DEL CAUCA                 CALI         VALLE DEL CAUCA                    CALI   VALLE DEL CAUCA              CALI        4652512.0        2075380.0          COLOMBIA         COLOMBIA      0.841                     25.7             68.584991                  4.0                       4.0                     2                   3            B+                       4                   4                           3                     81                81                84                         80                     93                             62                67           83                    69                77                        61          348
# 17    20241      ESTUDIANTE              URBANO              1               B      NO OFICIAL         BOGOTÁ, D.C.          BOGOTA D.C.            BOGOTÁ, D.C.             BOGOTA D.C.      BOGOTÁ, D.C.       BOGOTA D.C.        7937898.0        6778691.0          COLOMBIA         COLOMBIA      0.890                     19.6             73.038437                  4.0                       4.0                     6                   4            B+                       4                   4                           4                     97                99                88                         93                    100                             96                75           84                    75               100                        76          408
# 18    20241      ESTUDIANTE              URBANO              0               B      NO OFICIAL      VALLE DEL CAUCA                 CALI         VALLE DEL CAUCA                    CALI   VALLE DEL CAUCA              CALI        4652512.0        2075380.0          COLOMBIA         COLOMBIA      0.841                     25.7             54.377247                  3.0                       3.0                     3                   2            A1                       2                   2                           2                     28                24                35                         21                     20                             25                46           55                    48                44                        44          231
# 19    20241      ESTUDIANTE              URBANO              1               B      NO OFICIAL      VALLE DEL CAUCA              PALMIRA         VALLE DEL CAUCA                 PALMIRA   VALLE DEL CAUCA           PALMIRA        4652512.0         278358.0          COLOMBIA         COLOMBIA      0.841                     25.7             62.358109                  3.0                       3.0                     3                   3            B1                       4                   3                           4                     61                78                70                         81                     69                             95                60           78                    70                66                        75          343

# %% [markdown]
# ## **Valores nulos nuevas columnas**

# %%
print(df_icfes_2024.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626339 entries, 0 to 626338
# Data columns (total 39 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   periodo                        626339 non-null  int64
#  1   estu_estudiante                626339 non-null  object
#  2   cole_area_ubicacion            626339 non-null  object
#  3   cole_bilingue                  626339 non-null  int64
#  4   cole_calendario                626339 non-null  object
#  5   cole_naturaleza                626339 non-null  object
#  6   cole_depto_ubicacion           626339 non-null  object
#  7   cole_mcpio_ubicacion           626339 non-null  object
#  8   estu_depto_presentacion        626339 non-null  object
#  9   estu_mcpio_presentacion        626339 non-null  object
#  10  estu_depto_reside              626339 non-null  object
#  11  estu_mcpio_reside              626339 non-null  object
#  12  poblacion_depto                626322 non-null  float64
#  13  poblacion_mcpio                624839 non-null  float64
#  14  estu_nacionalidad              626339 non-null  object
#  15  estu_pais_reside               626339 non-null  object
#  16  idh_depto                      626322 non-null  float64
#  17  pobreza_monetaria_depto        606475 non-null  float64
#  18  estu_inse_individual           626339 non-null  float64
#  19  estu_nse_individual            626339 non-null  float64
#  20  estu_nse_establecimiento       626339 non-null  float64
#  21  fami_estratovivienda           626339 non-null  int64
#  22  desemp_c_naturales             626339 non-null  int64
#  23  desemp_ingles                  626339 non-null  object
#  24  desemp_lectura_critica         626339 non-null  int64
#  25  desemp_matematicas             626339 non-null  int64
#  26  desemp_sociales_ciudadanas     626339 non-null  int64
#  27  percentil_c_naturales          626339 non-null  int64
#  28  percentil_global               626339 non-null  int64
#  29  percentil_ingles               626339 non-null  int64
#  30  percentil_lectura_critica      626339 non-null  int64
#  31  percentil_matematicas          626339 non-null  int64
#  32  percentil_sociales_ciudadanas  626339 non-null  int64
#  33  punt_c_naturales               626339 non-null  int64
#  34  punt_ingles                    626339 non-null  int64
#  35  punt_lectura_critica           626339 non-null  int64
#  36  punt_matematicas               626339 non-null  int64
#  37  punt_sociales_ciudadanas       626339 non-null  int64
#  38  punt_global                    626339 non-null  int64
# dtypes: float64(7), int64(19), object(13)
# memory usage: 186.4+ MB
# None

# %%
# --- Resumen rápido de nulos por columna ---
nulos = df_icfes_2024.isna().sum()
porcentaje = (nulos / len(df_icfes_2024)) * 100
resumen_nulos = pd.DataFrame({
    'Nulos': nulos,
    '% Nulos': porcentaje.round(2)
})
print("\n--- Resumen de valores nulos por columna ---")
print(resumen_nulos[resumen_nulos['Nulos'] > 0])
# Out:
# --- Resumen de valores nulos por columna ---
#                          Nulos  % Nulos
# poblacion_depto             17     0.00
# poblacion_mcpio           1500     0.24
# idh_depto                   17     0.00
# pobreza_monetaria_depto  19864     3.17

# %%
# Filtro para EXTRANJERO
m = df_icfes_2024['estu_depto_reside'].str.strip().str.upper().eq('EXTRANJERO')

# Pone 0 (enteros) en poblaciones y 0.0 (floats) en idh/pobreza
df_icfes_2024.loc[m, ['poblacion_depto', 'poblacion_mcpio']] = 0
df_icfes_2024.loc[m, ['idh_depto', 'pobreza_monetaria_depto']] = 0.0

# Asegura tipos finales
df_icfes_2024['poblacion_depto'] = df_icfes_2024['poblacion_depto'].astype('Int64')
df_icfes_2024['poblacion_mcpio'] = df_icfes_2024['poblacion_mcpio'].astype('Int64')
df_icfes_2024[['idh_depto','pobreza_monetaria_depto']] = (
    df_icfes_2024[['idh_depto','pobreza_monetaria_depto']].astype(float)
)

# %%
# --- Resumen rápido de nulos por columna ---
nulos = df_icfes_2024.isna().sum()
porcentaje = (nulos / len(df_icfes_2024)) * 100
resumen_nulos = pd.DataFrame({
    'Nulos': nulos,
    '% Nulos': porcentaje.round(2)
})
print("\n--- Resumen de valores nulos por columna ---")
print(resumen_nulos[resumen_nulos['Nulos'] > 0])
# Out:
# --- Resumen de valores nulos por columna ---
#                          Nulos  % Nulos
# poblacion_mcpio           1483     0.24
# pobreza_monetaria_depto  19847     3.17

# %%
df_icfes_2024_final = df_icfes_2024.copy()

df_icfes_2024_final.to_csv("../data/curated/df_icfes_2024_final.csv", index=False, encoding="utf-8-sig")

print("Archivo guardado en data/curated/df_icfes_2024_final.csv")

print("Shape:", df_icfes_2024_final.shape)
# Out:
# Archivo guardado en data/curated/df_icfes_2024_final.csv
# Shape: (626339, 39)

# %%
print(df_icfes_2024_final.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626339 entries, 0 to 626338
# Data columns (total 39 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   periodo                        626339 non-null  int64
#  1   estu_estudiante                626339 non-null  object
#  2   cole_area_ubicacion            626339 non-null  object
#  3   cole_bilingue                  626339 non-null  int64
#  4   cole_calendario                626339 non-null  object
#  5   cole_naturaleza                626339 non-null  object
#  6   cole_depto_ubicacion           626339 non-null  object
#  7   cole_mcpio_ubicacion           626339 non-null  object
#  8   estu_depto_presentacion        626339 non-null  object
#  9   estu_mcpio_presentacion        626339 non-null  object
#  10  estu_depto_reside              626339 non-null  object
#  11  estu_mcpio_reside              626339 non-null  object
#  12  poblacion_depto                626339 non-null  Int64
#  13  poblacion_mcpio                624856 non-null  Int64
#  14  estu_nacionalidad              626339 non-null  object
#  15  estu_pais_reside               626339 non-null  object
#  16  idh_depto                      626339 non-null  float64
#  17  pobreza_monetaria_depto        606492 non-null  float64
#  18  estu_inse_individual           626339 non-null  float64
#  19  estu_nse_individual            626339 non-null  float64
#  20  estu_nse_establecimiento       626339 non-null  float64
#  21  fami_estratovivienda           626339 non-null  int64
#  22  desemp_c_naturales             626339 non-null  int64
#  23  desemp_ingles                  626339 non-null  object
#  24  desemp_lectura_critica         626339 non-null  int64
#  25  desemp_matematicas             626339 non-null  int64
#  26  desemp_sociales_ciudadanas     626339 non-null  int64
#  27  percentil_c_naturales          626339 non-null  int64
#  28  percentil_global               626339 non-null  int64
#  29  percentil_ingles               626339 non-null  int64
#  30  percentil_lectura_critica      626339 non-null  int64
#  31  percentil_matematicas          626339 non-null  int64
#  32  percentil_sociales_ciudadanas  626339 non-null  int64
#  33  punt_c_naturales               626339 non-null  int64
#  34  punt_ingles                    626339 non-null  int64
#  35  punt_lectura_critica           626339 non-null  int64
#  36  punt_matematicas               626339 non-null  int64
#  37  punt_sociales_ciudadanas       626339 non-null  int64
#  38  punt_global                    626339 non-null  int64
# dtypes: Int64(2), float64(5), int64(19), object(13)
# memory usage: 187.6+ MB
# None

# %% [markdown]
# * pobreza_monetaria_depto no tiene todos los departamentos, por eso sale con datos nulos
#
# * cuando en municipio o departamento sale "EXTRANJERO" en la otras columnas ponemos 0
#
# * Municipios que hay en dataicfes pero que no tiene equivalencia con los Municipios de data población:  "RIO IRO": None, "SIPI": None
#
# * Hay 16 Municipios que data ICFES tiene pero que no hay coincidencia con data Población Municipios, que corresponden a 1500 filas

# %% [markdown]
# ## **GREATE EXPECTATIONS**

# %%
df = pd.read_csv("../data/curated/df_icfes_2024_final.csv", encoding="utf-8-sig")

ge_df = PandasDataset(df)

print("Dataset listo para validaciones con Great Expectations 0.18.12")
print("Filas y columnas:", df.shape)
# Out:
# Dataset listo para validaciones con Great Expectations 0.18.12
# Filas y columnas: (626339, 39)

# %% [markdown]
# **Expectativas críticas**

# %%
# 1. Integridad
ge_df.expect_column_values_to_not_be_null("punt_global")


# 2. Dominio/rangos
ge_df.expect_column_values_to_be_between(
    "punt_global", 
    min_value=0, 
    max_value=500
)

# 3. Integridad
ge_df.expect_column_values_to_not_be_null("estu_depto_reside")



res1 = ge_df.expect_column_values_to_not_be_null("punt_global")
res2 = ge_df.expect_column_values_to_be_between("punt_global", min_value=0, max_value=500)
res3 = ge_df.expect_column_values_to_not_be_null("estu_depto_reside")

print(res1)
print(res2)
print(res3)
# Out:
# {
#   "success": true,
#   "expectation_config": {
#     "expectation_type": "expect_column_values_to_not_be_null",
#     "kwargs": {
#       "column": "punt_global",
#       "result_format": "BASIC"
#     },
#     "meta": {}
#   },
#   "result": {
#     "element_count": 626339,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }
# {
#   "success": true,
#   "expectation_config": {
#     "expectation_type": "expect_column_values_to_be_between",
#     "kwargs": {
#       "column": "punt_global",
#       "min_value": 0,
#       "max_value": 500,
#       "result_format": "BASIC"
#     },
#     "meta": {}
#   },
#   "result": {
#     "element_count": 626339,
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }
# {
#   "success": true,
#   "expectation_config": {
#     "expectation_type": "expect_column_values_to_not_be_null",
#     "kwargs": {
#       "column": "estu_depto_reside",
#       "result_format": "BASIC"
#     },
#     "meta": {}
#   },
#   "result": {
#     "element_count": 626339,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %% [markdown]
# **Otras Expectativas**

# %%
# 4. Tipo de dato
res4 = ge_df.expect_column_values_to_be_of_type("periodo", "int64")

# 5. Tipo de dato
res5 = ge_df.expect_column_values_to_be_of_type("estu_pais_reside", "str")

# 6. Dominio/rangos
ge_df.expect_column_values_to_be_between("pobreza_monetaria_depto", min_value=0, max_value=100)

# 7. Dominio/rangos
ge_df.expect_column_values_to_be_between("idh_depto", min_value=0, max_value=1)

# 8. Regla entre columnas
mask = ge_df["punt_global"] >= ge_df["punt_matematicas"]
res8 = {
    "success": mask.all(),
    "unexpected_count": (~mask).sum(),
    "unexpected_percent": round((~mask).sum() / len(ge_df) * 100, 4)
}



res4 = ge_df.expect_column_values_to_be_of_type("periodo", "int64")

res5 = ge_df.expect_column_values_to_be_of_type("estu_pais_reside", "str")

res6 = ge_df.expect_column_values_to_be_between("pobreza_monetaria_depto", min_value=0, max_value=100)

res7 = ge_df.expect_column_values_to_be_between("idh_depto", min_value=0, max_value=1)

res8 = {"success": mask.all(),"unexpected_count": (~mask).sum(),"unexpected_percent": round((~mask).sum() / len(ge_df) * 100, 4)}


print(res4)
print(res5)
print(res6)
print(res7)
print(res8)
# Out:
# {
#   "success": true,
#   "expectation_config": {
#     "expectation_type": "_expect_column_values_to_be_of_type__aggregate",
#     "kwargs": {
#       "column": "periodo",
#       "type_": "int64",
#       "result_format": "BASIC"
#     },
#     "meta": {}
#   },
#   "result": {
#     "observed_value": "int64"
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }
# {
#   "success": true,
#   "expectation_config": {
#     "expectation_type": "_expect_column_values_to_be_of_type__map",
#     "kwargs": {
#       "column": "estu_pais_reside",
#       "type_": "str",
#       "result_format": "BASIC"
#     },
#     "meta": {}
#   },
#   "result": {
#     "element_count": 626339,
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }
# {
#   "success": true,
#   "expectation_config": {
#     "expectation_type": "expect_column_values_to_be_between",
#     "kwargs": {
#       "column": "pobreza_monetaria_depto",
#       "min_value": 0,
#       "max_value": 100,
#       "result_format": "BASIC"
#     },
#     "meta": {}
#   },
#   "result": {
#     "element_count": 626339,
#     "missing_count": 19847,
#     "missing_percent": 3.168731310041367,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }
# {
#   "success": true,
#   "expectation_config": {
#     "expectation_type": "expect_column_values_to_be_between",
#     "kwargs": {
#       "column": "idh_depto",
#       "min_value": 0,
#       "max_value": 1,
#       "result_format": "BASIC"
#     },
#     "meta": {}
#   },
#   "result": {
#     "element_count": 626339,
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }
# {'success': True, 'unexpected_count': 0, 'unexpected_percent': 0.0}

# %% [markdown]
# **Expectation Suite**

# %%
# usar gx directamente
ge_path = os.path.abspath(os.path.join("..", "src", "validation", "gx"))
context = ge.get_context(context_root_dir=ge_path)

print("Contexto cargado correctamente desde:", ge_path)
# Out:
# Contexto cargado correctamente desde: g:\Mi unidad\UAO\SEMESTRES INGENIERÍA DE DATOS E I.A\SEMESTRE 5\ETL\GRUPO-1\ENTREGABLES-PROYECTO\PARTE 2\src\validation\gx

# %%
suite_name = "icfes_suite"

# Crear suite si no existe
if suite_name not in [s.name for s in context.list_expectation_suites()]:
    context.add_expectation_suite(expectation_suite_name=suite_name)
    print(f"Suite '{suite_name}' creada correctamente.")
else:
    print(f"La suite '{suite_name}' ya existe.")

print("Ubicación esperada:", "gx/expectations/icfes_suite.json")
# Out:
# Suite 'icfes_suite' creada correctamente.
# Ubicación esperada: gx/expectations/icfes_suite.json

# %%
# === 1. Registrar datasource ===
datasource_config = {
    "name": "runtime_pandas_datasource",
    "class_name": "Datasource",
    "execution_engine": {"class_name": "PandasExecutionEngine"},
    "data_connectors": {
        "default_runtime_data_connector_name": {
            "class_name": "RuntimeDataConnector",
            "batch_identifiers": ["default_identifier_name"]
        }
    }
}

try:
    context.add_datasource(**datasource_config)
    print("Datasource 'runtime_pandas_datasource' agregado correctamente.")
except Exception as e:
    print("Posiblemente ya existe el datasource:", e)

# === 2. Crear RuntimeBatchRequest ===
batch_request = RuntimeBatchRequest(
    datasource_name="runtime_pandas_datasource",
    data_connector_name="default_runtime_data_connector_name",
    data_asset_name="icfes_data",
    runtime_parameters={"batch_data": df_icfes_2024_final},
    batch_identifiers={"default_identifier_name": "default_id"},
)

# === 3. Crear Validator ===
validator = context.get_validator(
    batch_request=batch_request,
    expectation_suite_name="icfes_suite"
)

print("Validator creado correctamente con el dataset:", validator.active_batch.data.dataframe.shape)
# Out:
# Datasource 'runtime_pandas_datasource' agregado correctamente.
# Validator creado correctamente con el dataset: (626339, 39)

# %%
# === 1. Expectativas de integridad ===
validator.expect_column_values_to_not_be_null("punt_global")
validator.expect_column_values_to_not_be_null("estu_depto_reside")

# === 2. Expectativas de dominio / rangos ===
validator.expect_column_values_to_be_between("punt_global", min_value=0, max_value=500)
validator.expect_column_values_to_be_between("pobreza_monetaria_depto", min_value=0, max_value=100)
validator.expect_column_values_to_be_between("idh_depto", min_value=0, max_value=1)

# === 3. Expectativas de tipo de dato ===
validator.expect_column_values_to_be_of_type("periodo", "int64")
validator.expect_column_values_to_be_of_type("estu_pais_reside", "str")

# === 4. Relación entre columnas ===
validator.expect_column_pair_values_A_to_be_greater_than_B(
    column_A="punt_global",
    column_B="punt_matematicas",
    or_equal=True,
    meta={"description": "punt_global debe ser >= punt_matematicas"}
)

# === 5. Guardar la suite actualizada ===
validator.save_expectation_suite(discard_failed_expectations=False)
print("Expectation suite actualizada y guardada en:")
print("src/validation/gx/expectations/icfes_suite.json")
# Out:
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# Expectation suite actualizada y guardada en:
# src/validation/gx/expectations/icfes_suite.json

# %% [markdown]
# **Checkpoint**

# %%
# === Crear el checkpoint ===
checkpoint_name = "checkpoint_icfes_curated"

checkpoint = SimpleCheckpoint(
    name=checkpoint_name,
    data_context=context,
)

# === Ejecutar el checkpoint con la validación explícita ===
results = checkpoint.run(
    validations=[
        {
            "batch_request": batch_request,
            "expectation_suite_name": "icfes_suite",
        }
    ]
)

print("Checkpoint ejecutado correctamente.")
# Out:
# Calculating Metrics:   0%|          | 0/45 [00:00<?, ?it/s]
# Checkpoint ejecutado correctamente.

# %% [markdown]
# **reporte HTML**

# %%
# === Generar y abrir Data Docs ===
context.build_data_docs()  # genera el HTML
local_site_path = context.get_docs_sites_urls()[0]["site_url"]
print("Data Docs generados en:", local_site_path)
# Out:
# Data Docs generados en: file://g:\Mi unidad\UAO\SEMESTRES INGENIERÍA DE DATOS E I.A\SEMESTRE 5\ETL\GRUPO-1\ENTREGABLES-PROYECTO\PARTE 2\src\validation\gx\uncommitted/data_docs/local_site/index.html

# %% [markdown]
# Las validaciones de calidad se ejecutaron sobre el dataset curated (df_icfes_2024_final), ya que esta capa representa la versión final, limpia y consolidada de los datos antes de su análisis o carga al Data Warehouse. En este punto se garantiza la integridad, los tipos de datos y los rangos definidos en las expectativas, asegurando que la información final cumpla con los estándares de calidad establecidos.
