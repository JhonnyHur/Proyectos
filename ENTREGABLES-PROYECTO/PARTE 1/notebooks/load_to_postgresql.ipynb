# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy import text

# %% [markdown]
# **Cargar CSV**

# %%
csv_path = "../data_transformed/data_transformed.csv"
df = pd.read_csv(csv_path)
print(f"📥 CSV cargado: {df.shape}")
# Out:
# C:\Users\braya\AppData\Local\Temp\ipykernel_18704\3834075712.py:2: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path)
# 📥 CSV cargado: (626339, 53)

# %% [markdown]
# **Conexión PostgreSQL**

# %%
pg_user = "transformed"
pg_password = "etl25"
pg_host = "localhost"
pg_port = "5432"
pg_db = "icfes_transformed"

pg_url = f"postgresql+psycopg2://{pg_user}:{pg_password}@{pg_host}:{pg_port}/{pg_db}"
pg_engine = create_engine(pg_url)

# %% [markdown]
# **Inserción datos en PostgreSQL**

# %%
df.to_sql(
    "data_transformed",
    con=pg_engine,
    if_exists="replace",   # crea/reemplaza la tabla
    index=False,
    chunksize=10000
)

print(f"✅ Datos insertados en {pg_db}.data_transformed")
print(f"📊 Filas: {df.shape[0]:,} | Columnas: {df.shape[1]}")
# Out:
# ✅ Datos insertados en icfes_transformed.data_transformed
# 📊 Filas: 626,339 | Columnas: 53
